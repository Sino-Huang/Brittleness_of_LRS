# %% [markdown]
# ## output structure
#
# ```
# dict: {<data_id> : {
#                     "spell_correction_txt": type->str,
#                     "embedding": type-> ndarray(768,),
#                     "phrase_chunking_sentence": type -> lst(str)
#                     "phrase_chunking_tag": type-> lst(str),
#                     'verb_phrase_arr': lst(str)
#                     'noun_phrase_arr': lst(str)
#                     }
#       }
# ```

# %% [markdown]
# ## Sent emb model

# %%
# Config
SEN_EMB_DIM = 768
# import packages 
import numpy as np
import torch
import re
import pickle 
import os
from tqdm import tqdm_notebook as tqdm
from scipy.spatial.distance import cosine
from transformers import AutoModel, AutoTokenizer
from sentence_transformers import SentenceTransformer

# try another way
model = SentenceTransformer('sentence-transformers/gtr-t5-xl')

# %% [markdown]
# ## Spell correction

# %%
import pkg_resources
from symspellpy import SymSpell
from symspellpy import Verbosity
from nltk.stem import PorterStemmer 
import string
from nltk.stem import WordNetLemmatizer
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('words')

# Set up sym_spell
sym_spell = SymSpell(max_dictionary_edit_distance=2, prefix_length=7)
dictionary_path = pkg_resources.resource_filename(
    "symspellpy", "frequency_dictionary_en_82_765.txt"
)
bigram_path = pkg_resources.resource_filename(
    "symspellpy", "frequency_bigramdictionary_en_243_342.txt"
)
# term_index is the column of the term and count_index is the
# column of the term frequency
sym_spell.load_dictionary(dictionary_path, term_index=0, count_index=1)
sym_spell.load_bigram_dictionary(bigram_path, term_index=0, count_index=2)

ps = PorterStemmer()
wnl = WordNetLemmatizer()
english_vocab = set(w.lower() for w in nltk.corpus.words.words())
def correct(w):
    if all([not c.isalpha() for c in w]): return w
    
    word = w
    
    # Fix for strings with punctuations in them
    # Otherwise, it will try to spellcheck with the punctuation included which messes up results
    word_no_punc = w.translate(str.maketrans(string.punctuation, ' '*len(string.punctuation)))
    split = word_no_punc.split()
    l = len(split)
    if l > 1:
        corrected = []
        i = 0
        while i < l:
            if i == l-1:
                corrected.append(correct(split[i]))
                break
        
            # if the words combined are english, then consider it as one word
            tmp = split[i] + split[i+1]
            if wnl.lemmatize(word=tmp) in english_vocab or ps.stem(tmp) in english_vocab:
                corrected.append(tmp)
                i += 1
            # otherwise, spellcheck them separately
            else:
                corrected.append(correct(split[i]))
            i += 1
        return corrected
    else:
        word_no_punc = word_no_punc.strip()
    
    o = sym_spell.lookup(word_no_punc,
        Verbosity.CLOSEST,
        max_edit_distance = 2,
        transfer_casing = True)
    
    if not o: return w

    word = o[0].term
    if w[0].isupper():
        word = word[0].upper() + ''.join(word[1: ])

    start_punc = end_punc = ''
    
    # Get start punctuation
    for c in w:
        if c in string.punctuation:
            start_punc += c
        else:
            break

    # Get end punctuation
    for c in reversed(w):
        if c in string.punctuation:
            end_punc = c + end_punc
        else:
            break
            
    return start_punc + word + end_punc

def spellcheck_keep_punctuation(sentence):
    # Replace apostrophe/short words 
    # specific
    sentence = re.sub(r"won\'t", "will not", sentence)
    sentence = re.sub(r"can\'t", "can not", sentence)

    # general
    sentence = re.sub(r"n\'t", " not", sentence)
    sentence = re.sub(r"\'re", " are", sentence)
    sentence = re.sub(r"\'s", " is", sentence)
    sentence = re.sub(r"\'d", " would", sentence)
    sentence = re.sub(r"\'ll", " will", sentence)
    sentence = re.sub(r"\'t", " not", sentence)
    sentence = re.sub(r"\'ve", " have", sentence)
    sentence = re.sub(r"\'m", " am", sentence)
    # add space to punctuation 
    sentence = sentence.translate(str.maketrans({key: " {0} ".format(key) for key in string.punctuation}))
    corrected = []
    for word in sentence.split():
        corrected_word = correct(word)
        if isinstance(corrected_word, list):
            corrected.extend(corrected_word)
        else:
            corrected.append(corrected_word)
    phrase = ' '.join(corrected).lower()
    
    return phrase
# Out:
# [nltk_data] Downloading package wordnet to /home/sukai/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/sukai/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package words to /home/sukai/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %% [markdown]
# ## Sentence embedding

# %%
def convert_to_sentence_embedding(raw_sentence):
    preprocessed_sentence = spellcheck_keep_punctuation(raw_sentence)
    # Get the embeddings
    with torch.no_grad():
        embeddings = model.encode(preprocessed_sentence) # shape (768,)
    return embeddings # shape : [<SENTENCE_EMB_DIM>,]

# %% [markdown]
# ## Load instruction pkl and process the text

# %%
training_instruction_path = "train_data/training_instruction_dict_raw.pkl"
test_pos_ins_path = "test_data/testing_positive_instruction_dict_raw.pkl"
test_neg_ins_path = "test_data/testing_negative_instruction_dict_raw.pkl"

# %% [markdown]
# ## Phrase chunking model

# %%
from flair.data import Sentence
from flair.models import SequenceTagger
pos_model = SequenceTagger.load("flair/chunk-english")
# Out:
# /home/sukai/anaconda3/envs/atari/lib/python3.8/site-packages/huggingface_hub/file_download.py:588: FutureWarning: `cached_download` is the legacy way to download files from the HF hub, please consider upgrading to `hf_hub_download`
#   warnings.warn(
# 2022-11-24 12:20:38,999 loading file /home/sukai/.flair/models/chunk-english/5b53097d6763734ee8ace8de92db67a1ee2528d5df9c6d20ec8e3e6f6470b423.d81b7fd7a38422f2dbf40f6449b1c63d5ae5b959863aa0c2c1ce9116902e8b22
# 2022-11-24 12:20:39,266 SequenceTagger predicts: Dictionary with 45 tags: <unk>, O, B-NP, E-NP, I-NP, S-PP, S-VP, S-SBAR, S-ADVP, S-NP, S-ADJP, B-VP, E-VP, B-PP, E-PP, I-VP, S-PRT, B-ADVP, E-ADVP, B-ADJP, E-ADJP, B-CONJP, I-CONJP, E-CONJP, I-ADJP, B-SBAR, E-SBAR, S-INTJ, I-ADVP, I-PP, B-UCP, I-UCP, E-UCP, S-LST, B-PRT, I-PRT, E-PRT, S-CONJP, B-INTJ, E-INTJ, I-INTJ, B-LST, E-LST, <START>, <STOP>

# %%
def convert_to_phrase_chunking(raw_sentence):
    preprocessed_sentence = spellcheck_keep_punctuation(raw_sentence)
    preprocessed_sentence = Sentence(preprocessed_sentence)
    # Get the embeddings
    with torch.no_grad():
        pos_model.predict(preprocessed_sentence) # shape (768,)
    return ([w.data_point.text for w in preprocessed_sentence.get_labels()],
            [w.value for w in preprocessed_sentence.get_labels()]) # type: lst(str)

# %%
s = convert_to_phrase_chunking("go under the two skulls and down the ladder .")

# %%
s = convert_to_phrase_chunking("wait for the steps on the right to appear , then climb and into the next area .")

# %%
s
# Out:
# (['wait',
#   'for',
#   'the steps',
#   'on',
#   'the right',
#   'to appear',
#   'climb',
#   'and',
#   'into',
#   'the next area'],
#  ['VP', 'PP', 'NP', 'PP', 'NP', 'VP', 'VP', 'PP', 'PP', 'NP'])

# %%
def preprocess_instruction(text_path):
    new_dict = dict()
    with open(text_path, 'rb') as f:
        instruction_dict = pickle.load(f)
        for key,val in tqdm(instruction_dict.items()):
            phrase_chunking_str, phrase_chunking_tag = convert_to_phrase_chunking(val)
            new_dict[key] = {"spell_correction_txt": spellcheck_keep_punctuation(val),
                             "embedding": convert_to_sentence_embedding(val),
                             "phrase_chunking_sentence": phrase_chunking_str,
                             "phrase_chunking_tag": phrase_chunking_tag}
    return new_dict

# %%
training_instruction_sentence_emb_dict = preprocess_instruction(training_instruction_path)
test_pos_ins_sentence_emb_dict = preprocess_instruction(test_pos_ins_path)
test_neg_ins_sentence_emb_dict = preprocess_instruction(test_neg_ins_path)
# Out:
# 100%|███████████████████████████████████████| 5655/5655 [02:09<00:00, 43.77it/s]
# 100%|█████████████████████████████████████████| 608/608 [00:13<00:00, 43.97it/s]
# 100%|█████████████████████████████████████████| 607/607 [00:13<00:00, 44.33it/s]

# %% [markdown]
# ## save pkl

# %%
with open('train_data/training_instruction_sen_emb_phrase_chunk.pkl', 'wb') as f:
    pickle.dump(training_instruction_sentence_emb_dict, f)
with open('test_data/test_pos_ins_sen_emb_phrase_chunk.pkl', 'wb') as f:
    pickle.dump(test_pos_ins_sentence_emb_dict, f)
with open('test_data/test_neg_ins_sen_emb_phrase_chunk.pkl', 'wb') as f:
    pickle.dump(test_neg_ins_sentence_emb_dict, f)

# %%
def replacewords(original_sent, old_phrase, new_phrase):
    # will return the new sentence
    start_ind = original_sent.find(old_phrase)
    if start_ind == -1:
        return None
    temp = old_phrase
    if start_ind != 0: 
        temp = " " + temp
    if start_ind + len(old_phrase) != len(original_sent):
        temp = temp + " "
    old_phrase = temp
    phrase_len = len(old_phrase)
    start_ind = original_sent.find(old_phrase)
    if start_ind == -1:
        return None
    else:
        new_sent = original_sent[:start_ind] + " " + new_phrase + " " + original_sent[start_ind + phrase_len:]
        return new_sent

# %% [markdown]
# ## Analyse Actions

# %%
# we should catch the VP PP and VP
ACTION_PATTERNS = [
    ['VP', 'PP'],
    ['VP'],
]

# %%
def loop_pattern(pattern, left_tag_arr, left_sentence, left_global_indices_arr):
    # should output the indices of found pattern
    pattern_len = len(pattern)
    if pattern_len > len(left_tag_arr):
        return None
    for start_ind in range(len(left_tag_arr) - pattern_len + 1):
        is_found = True
        for pattern_ind in range(pattern_len):
            if pattern[pattern_ind] != left_tag_arr[start_ind + pattern_ind]:
                is_found = False 
                break
        if is_found:
            # means we found the pattern, we trim the left_global_indices_arr 
            # get the indices of the pattern
            pattern_local_indices = list(range(start_ind, start_ind+ pattern_len))
            # return phrase, pattern, left_tag_arr, left_sentence, left_global_indices_arr
            phrase = left_sentence[start_ind : start_ind+ pattern_len]
            left_tag_arr = left_tag_arr[:start_ind] + ["PH"] + left_tag_arr[start_ind+ pattern_len:]
            left_sentence = left_sentence[:start_ind] + ["PH"] + left_sentence[start_ind+ pattern_len:]
            left_global_indices_arr = left_global_indices_arr[:start_ind] + left_global_indices_arr[start_ind+ pattern_len:]
            return phrase, pattern, left_tag_arr, left_sentence, left_global_indices_arr
    # end loop and find nothing means we need to change to another pattern to search 
    return None 

def find_pattern(pattern_arr, original_sentence, original_tag_arr): # type: pattern_arr, str, tag_arr
    left_tag_arr = original_tag_arr
    left_sentence = original_sentence
    left_global_indices_arr = list(range(len(left_sentence)))
    output_phrase_arr = []
    output_pattern_arr = []
    for pattern in pattern_arr:
        while True:
            output = loop_pattern(pattern, left_tag_arr, left_sentence, left_global_indices_arr)
            if output is not None:
                # means we found something, 
                phrase, the_pattern, left_tag_arr, left_sentence, left_global_indices_arr = output
                output_phrase_arr.append(phrase)
                output_pattern_arr.append(the_pattern)
            else:
                # we go for the next pattern
                break
    return output_phrase_arr, output_pattern_arr

# %%
# check all the verbs 
with open('train_data/training_instruction_sen_emb_phrase_chunk.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
print(data[0]['spell_correction_txt'])
print(data[0]['phrase_chunking_sentence'])
print(data[0]['phrase_chunking_tag'])

# we should catch the VERB ADP / VERB / VERB ADV CCONJ ADV / VERB ADV / VERB CCONJ VERB phrases
# Out:
# climb up the ladder until you reach the top of the purple room
# ['climb', 'up', 'the ladder', 'until', 'you', 'reach', 'the top', 'of', 'the purple room']
# ['VP', 'PP', 'NP', 'SBAR', 'NP', 'VP', 'NP', 'PP', 'NP']

# %%
find_pattern(ACTION_PATTERNS,
             data[0]['phrase_chunking_sentence'],
             data[0]['phrase_chunking_tag'])
# Out:
# ([['climb', 'up'], ['reach']], [['VP', 'PP'], ['VP']])

# %%
# collect all the verb phrase in the training data 
verb_phrase_set = set()

for key, val in data.items():
    phrase_arr, _ = find_pattern(ACTION_PATTERNS,
                                 val['phrase_chunking_sentence'],
                                 val['phrase_chunking_tag'])

    # process the phrase_arr
        
    val['verb_phrase_arr'] = []
    for phrase in phrase_arr:
        str_phrase = ' '.join(phrase)
        # add the phrase arr to data
        val['verb_phrase_arr'].append(str_phrase)
        verb_phrase_set.add(str_phrase)

# %%
len(verb_phrase_set)
# Out:
# 1095

# %%
verb_phrase_set
# Out:
# {'to meet',
#  'stay for',
#  'have disappear',
#  'left toward',
#  'are above',
#  'continue left',
#  'move on',
#  'move to advance to',
#  'to turn',
#  'are go to try',
#  'are come and using',
#  'gets disappears',
#  'slightly go to',
#  'wait to see',
#  'comes go',
#  'move left to jump',
#  'wait behind',
#  'make move on',
#  'stay let crab',
#  'die on',
#  'gets disappear',
#  'go',
#  'move left jumping',
#  'let over',
#  'run through',
#  'is left of',
#  'moving to',
#  'reaches',
#  'fall jump up',
#  'move to left and jump',
#  'go climb to',
#  'go above',
#  'jump up',
#  'touched',
#  'walks',
#  'spawn',
#  'was climb',
#  'surfaces',
#  'run right while',
#  'stand towards',
#  'pause to let',
#  'wait and going',
#  'to be',
#  'move from',
#  'to avoid being hit by',
#  'end on',
#  'switch between',
#  'hop on',
#  'stay fixed to',
#  'to give',
#  'to face',
#  'to left',
#  'move left take',
#  'again take',
#  'wait to',
#  'go to climb',
#  'are appearing and disappearing',
#  'walk by',
#  'climb above',
#  'do not get',
#  'do not touch',
#  'climb top',
#  'move left to go to',
#  'go left avoiding',
#  'jump after',
#  'caught',
#  'to pause',
#  'move left to right',
#  'bite by',
#  'start to go',
#  'slowly climb',
#  'climb off',
#  'to raise',
#  'clip',
#  'lands',
#  'sitting',
#  'goes',
#  'to cross',
#  'flash',
#  'running to',
#  'to spawn on',
#  'coming',
#  'get into',
#  'stay put on',
#  'are on',
#  'slowly left',
#  'dodging',
#  'can go',
#  'again jump over',
#  'hanging to',
#  'go left and into',
#  'turn left and jump',
#  'avoid hitting',
#  'must cross with',
#  'are waiting for',
#  'stop right before',
#  'wait in',
#  'clip down',
#  'climb then going',
#  'should not caught',
#  'hop up',
#  'stop near by',
#  'climbing',
#  'to bounce',
#  'move toward',
#  'go left and jump',
#  'appears then quickly jump to',
#  'jump and cross',
#  'slowly walking',
#  'going left jump',
#  'edge',
#  'appears then walk to',
#  'stop walk',
#  'again wait',
#  'to jump',
#  'club',
#  'are running for',
#  'hanging',
#  'approach',
#  'hold',
#  'to stop and proceed',
#  'is climbing',
#  'pause at',
#  'stand and go',
#  'walk along',
#  'keep running',
#  'to get on',
#  'to left through',
#  'move left and past',
#  'getting bitten by',
#  'returned',
#  'to clip',
#  'left over',
#  'let',
#  'will appear on',
#  'head',
#  'pause for',
#  'to re',
#  'to complete',
#  'show',
#  'was bitten by',
#  'again moved towards',
#  'take',
#  'to go down',
#  'go passed',
#  'create',
#  'exit',
#  'go down',
#  'descend',
#  'jump off going',
#  'go straight',
#  'touching',
#  'continue to walk to',
#  'go left under',
#  'little left',
#  'jump down',
#  'disappear going to',
#  'wait',
#  'stop at',
#  'will be going',
#  'simply standing on',
#  'face left',
#  'get to',
#  'view',
#  'will die',
#  'to come',
#  'climb towards',
#  'go left jumping',
#  'get off',
#  'are showing',
#  'return to',
#  'slightly get',
#  'slightly move towards',
#  'try to jump',
#  'comes near',
#  'grab onto',
#  'check',
#  'jump for',
#  'wait for',
#  'turn',
#  'do not go',
#  'to climb up',
#  'going',
#  'stand to',
#  'hit with',
#  'to appear on',
#  'collected with',
#  'will be',
#  'is shown',
#  'to appear then step',
#  'will cross',
#  'climb on',
#  'to solidify',
#  'appear and walk over',
#  'try to jump over',
#  'once left',
#  'are come to',
#  'quickly walk',
#  'to using',
#  'jump then keep running',
#  'hop from',
#  'reaching to',
#  'carefully watching',
#  'try',
#  'carefully wait for',
#  'place',
#  'try to go',
#  'continue to do',
#  'get out',
#  'left and stop',
#  'get on',
#  'stood',
#  'moving',
#  'to pass below',
#  'think for',
#  'then stop',
#  'wait and move',
#  'climb and jump',
#  'slightly left',
#  'is coming',
#  'time',
#  'slightly going to',
#  'return after',
#  'move behind',
#  'disappear before',
#  'pause before',
#  'move with',
#  'hang from',
#  'step off',
#  'escape',
#  'go slightly coming',
#  'comes',
#  'hit and fall by',
#  'come down',
#  'go left and stop between',
#  'disappears into',
#  'turn to',
#  'disappears',
#  'will be blocked by',
#  'miss',
#  'to de',
#  'to disappear walk to',
#  'to avoid',
#  'walk up',
#  'turn left move',
#  'wait to pass',
#  'turn to face',
#  'using to rope',
#  'stuck then climb',
#  'done move',
#  'hope onto',
#  'to reach',
#  'jumping from',
#  'jumping in',
#  'move left have',
#  'climb of',
#  'killed by',
#  'to clip on',
#  'slightly go',
#  'do not jump',
#  'land on',
#  'to down jump',
#  'running and climb upside',
#  'getting electrocuted',
#  'go left',
#  'move into',
#  'stand at',
#  'to become',
#  'try to move',
#  'walking',
#  'start walking',
#  'go through',
#  'to pass before',
#  'turn and walk to',
#  'slightly stand',
#  'perform',
#  'do not cross over',
#  'spoiled',
#  'do not get afraid move',
#  'keep moving to',
#  'go slightly jump',
#  'continue climbing up',
#  'suddenly return',
#  'repeat for',
#  'used for',
#  'watch for',
#  'go slow',
#  'to safeguard from',
#  'crossed',
#  'left onto',
#  'proceed',
#  'going jump',
#  'face left on',
#  'claim',
#  'wait to re spawn',
#  'continue to',
#  'slightly climb down',
#  'walk over',
#  'retrieve',
#  'twice going',
#  'die by',
#  'struck',
#  'walk to',
#  'stay put for',
#  'keep',
#  'stand',
#  'changes',
#  'stops falling',
#  'going watching',
#  'move to go',
#  'passes by',
#  'to avoid getting shocked by',
#  'remain on',
#  'will walking and cross',
#  'to appear then run',
#  'appears jump',
#  'timing',
#  'walk',
#  'hang',
#  'stand on',
#  'slightly walk',
#  'continue walking',
#  'stop walking',
#  'disappear take',
#  'will be stocked',
#  'fully climb',
#  'slowly move to',
#  'stand still watching',
#  'turn towards',
#  'standing in',
#  'to go from',
#  'try to climb up',
#  'move towards',
#  'is walking',
#  'running into',
#  'shows',
#  'again climb down',
#  'hide between',
#  'go left slow',
#  'do not try to cross',
#  'has passed',
#  'just going to',
#  'to spawn',
#  'walks past',
#  'crossing',
#  'again move towards',
#  'go slightly left',
#  'hop onto',
#  'continue walking towards',
#  'climbing up',
#  'disappears walk',
#  'slowly running',
#  'to disappear take',
#  'begin to jump over',
#  'move up',
#  'continue going down',
#  'climbed',
#  'appears run to',
#  'are not shining',
#  'keep running to',
#  'unfortunately attack',
#  'is moving',
#  'pause',
#  'are faded',
#  'down take',
#  'run to',
#  'is going',
#  'stand near',
#  'to stop',
#  'collect',
#  'escape to',
#  'starting',
#  'gets disappear on',
#  'to rope',
#  'needed',
#  'keep walking',
#  'drop from',
#  'hope',
#  'bounce',
#  'run in',
#  'go left jump over',
#  'jump to grab',
#  'break through',
#  'stopping between',
#  'running for',
#  'drop',
#  'continue up',
#  'to come stand',
#  'go towards',
#  'run',
#  'go up',
#  'hitting',
#  'claim up',
#  'to disappear',
#  'avoid getting bitten by',
#  'got escaped from',
#  'jump above',
#  'avoiding',
#  'cross over',
#  'wait then move',
#  'going for',
#  'go left toward',
#  'run into',
#  'to hop over',
#  'go past',
#  'jumped',
#  'do not make',
#  'little wait to cross',
#  'jump toward',
#  'little move',
#  'waling and running for',
#  'playing',
#  'jumping and running for',
#  'wait and reach',
#  'screwed to',
#  'wait to cross',
#  'go and climb',
#  'appears by',
#  'run between',
#  'go to get',
#  'stay hanging',
#  'running and jumping after',
#  'will be stop',
#  'getting to',
#  'once going',
#  'stop and wait before',
#  'appears walk to',
#  'disappear repeat',
#  'touched on',
#  'dodge',
#  'keep climbing in',
#  'go left into',
#  'keeping going',
#  'hang on',
#  'talk',
#  'slightly move to',
#  'was running to',
#  'walking towards',
#  'stop going',
#  'cautiously descend',
#  'climbs',
#  'wait and go',
#  'being',
#  'is showing',
#  'go jump across',
#  'running past',
#  'keep going to get to',
#  'was walking by',
#  'exit to',
#  'turn left',
#  'slowly go',
#  'lands in',
#  'have',
#  'try crossing to',
#  'die',
#  'go left near',
#  'left along',
#  'collected',
#  'grab',
#  'is on',
#  'left and ridden',
#  'hop to',
#  'slide down',
#  'move down',
#  'stop',
#  'move to climb up',
#  'again go',
#  'stop and straight go',
#  'shuffle to',
#  'bump into',
#  'past',
#  'play',
#  'walking on',
#  'have to jump',
#  'using and running',
#  'left to get',
#  'go left hopping',
#  'briefly enter',
#  'moved to',
#  'walk into',
#  'jumps to',
#  'standing on',
#  'to enter',
#  'jump to',
#  'jumping for',
#  'slightly climb up',
#  'move through',
#  'to drop',
#  'just climb',
#  'slipped',
#  'move past',
#  'again jump',
#  'to go into',
#  'forces',
#  'pop',
#  'to be filled',
#  'climb upside',
#  'to get onto',
#  'to start',
#  'making',
#  'so return',
#  'get near',
#  'to change',
#  'to right see',
#  'step left',
#  'jump past',
#  'left making',
#  'to disappear before',
#  'jumping onto',
#  'reset',
#  'goes on',
#  'got',
#  'go left down',
#  'face',
#  'jumped over',
#  'turning',
#  'reach to',
#  'to bitten',
#  'back',
#  'moving toward',
#  'walk for',
#  'bump',
#  'keep standing',
#  'are using',
#  'go left watching',
#  'are near by',
#  'jump over',
#  'to materialize',
#  'jump and catch',
#  'keep heading',
#  'to clear',
#  'walks to',
#  'are walking in',
#  'are',
#  'continue walking to',
#  'stay fixed at',
#  'run past',
#  'jumps',
#  'slightly jump',
#  'see',
#  'stop and wait',
#  'gets',
#  'is flashing',
#  'moves to',
#  'stopping before',
#  'to clear before',
#  'to reappear',
#  'jump in',
#  'proceed to',
#  'running and going for',
#  'cautiously approach',
#  'stay beneath',
#  'rolling',
#  'jump to catch',
#  'to pass',
#  'is near',
#  'left into',
#  'are let down',
#  'down and running',
#  'jump and run',
#  'came from',
#  'will be lost',
#  'is gone',
#  'be',
#  'move left wait',
#  'moves from',
#  'go left get',
#  'go left for',
#  'pick',
#  'climb up',
#  'swing on',
#  'move slightly left',
#  'go left towards',
#  'to pick',
#  'watching',
#  'make move to',
#  'stand in',
#  'climbing down',
#  'keep moving',
#  'waiting in',
#  'waiting and going to',
#  'reappears',
#  'left to',
#  'go slightly stop on',
#  'goes down',
#  'continue going',
#  'to go up',
#  'appears at',
#  'to walk into',
#  'jumping and walking',
#  'go left move to ladder',
#  'go left to barrier',
#  'to be start',
#  'stay in',
#  'little move in',
#  'coming to',
#  'going from',
#  'wait over',
#  'stand over',
#  'climbs to',
#  'jumps up',
#  'move to',
#  'remain up',
#  'turns',
#  'get behind',
#  'go with',
#  'to snake',
#  'to move across',
#  'continue climbing',
#  'moves',
#  'keep walking to',
#  'standing and thinking for',
#  'were to',
#  'halt',
#  'arriving towards',
#  'rope',
#  'seeing',
#  'look',
#  'pushing',
#  'catch',
#  'stop before',
#  'jump into',
#  'to be out',
#  'move in',
#  'jump as',
#  'move left and jump over',
#  'press',
#  'to retrieve',
#  'again slightly move towards',
#  'jump before',
#  'staying behind',
#  'keep doing',
#  'turned',
#  'wait facing',
#  'stand between',
#  'stopped',
#  'ladder',
#  'just walk',
#  'go left stop at',
#  'jump to climb',
#  'also running',
#  'ascend',
#  'start',
#  'jump off',
#  'avoid hitting or touching',
#  'appears',
#  'go toe',
#  'to hit',
#  'get disintegrated by',
#  'is not shining',
#  'to past',
#  'getting',
#  'attempt to jump',
#  'exit on',
#  'do',
#  'running',
#  'stay at',
#  'stop near',
#  'is jumping across',
#  'go left jumping on',
#  'proceed to jump',
#  'crosses',
#  'move across',
#  'moving under',
#  'jump twice going',
#  'start climbing',
#  'comes on',
#  'hops',
#  'to jump over',
#  'moving towards',
#  'reach',
#  'shuffle',
#  'affect',
#  'to left move',
#  'shuffle on',
#  'stay put after',
#  'move left toward',
#  'observe',
#  'fall',
#  'start to run',
#  'disappear',
#  'keep going',
#  'try to hop over',
#  'waiting for',
#  'to collected',
#  'just waiting',
#  'getting hit',
#  'was standing in',
#  'using to ladder in',
#  'jump left onto',
#  'jump going',
#  'step',
#  'ride',
#  'go to',
#  'jumping and catching',
#  'walk across',
#  'jump under',
#  'to appear',
#  'go left passed',
#  'to get',
#  'jumping on',
#  'jump at',
#  'move left waiting',
#  'collects',
#  'to appear then jump to',
#  'slowly running for',
#  'to grab',
#  'thinking for',
#  'walk toward',
#  'jump across',
#  'clear',
#  'keep going left stop at',
#  'disappear towards',
#  'do not do',
#  'to go',
#  'left to right walk',
#  'to approach',
#  'waiting to',
#  'touch',
#  'walk down',
#  'move left to',
#  'grasp',
#  'climb',
#  'are standing',
#  'walk past',
#  'wait near',
#  'falling from',
#  'clime',
#  'disappear go',
#  'climb to move',
#  'go on',
#  'walk and ladder',
#  'carefully following behind',
#  'watched to skull',
#  'comeback from',
#  'has',
#  'get struck by',
#  'avoiding getting disintegrated by',
#  'found',
#  'to come into',
#  'is climbing from',
#  'appearing and disappearing',
#  'stay out',
#  'was stop running',
#  'landing',
#  'got move',
#  'walk towards',
#  'left towards',
#  'climb through',
#  'are jumping across',
#  'appear and disappear',
#  'climbing on',
#  'continue',
#  'again move',
#  're',
#  'turn and face',
#  'move to cross with',
#  'is',
#  'head up',
#  'to finish',
#  'was',
#  'start going down',
#  'climb to',
#  'shuffle down',
#  'collecting',
#  'claim down',
#  'do not move from',
#  'continue to go',
#  'switches',
#  'make',
#  'go under',
#  'does not move',
#  'immediately go',
#  'continue toward',
#  'reached',
#  'jump',
#  'sword',
#  'come to',
#  'keep going to left',
#  'repeat',
#  'to stop blinking',
#  'standing for',
#  'nearing',
#  'to avoid getting bitten by',
#  'solidify',
#  'stay above',
#  'is at',
#  'slightly going',
#  'to catch',
#  'move',
#  'to get to',
#  'shuffle up',
#  'taking',
#  'avoid',
#  'head towards',
#  'left by',
#  'watch',
#  'go repeat',
#  'wait to jump over',
#  'to do',
#  'disappear make',
#  'got struck',
#  'step down',
#  'climb down',
#  'jumping',
#  'afterwards climbing',
#  'passed',
#  'escaped',
#  'follow',
#  'go to left by',
#  'using to ladder',
#  'once move',
#  'climb for',
#  'to evade',
#  'blink to continue',
#  'back down',
#  'continuing',
#  'move left and jump',
#  'grabbing',
#  'move upon',
#  'wait between',
#  'step over',
#  'waiting',
#  'jump onto',
#  'move and stop',
#  'hover over',
#  'stops',
#  'run on',
#  'then run',
#  'passes',
#  'left observing',
#  'do not cross',
#  'stop and watch for',
#  'clumping',
#  'was move to',
#  'wait and cross',
#  'get down',
#  'to avoid getting hit',
#  'turn to left',
#  'getting caught',
#  'to cross to',
#  'to ladder',
#  'stopping',
#  'enter',
#  'moving from',
#  'walk with',
#  'running and felt',
#  'slightly move',
#  'jump to get',
#  'wait at',
#  'jump to go',
#  'went',
#  'are gone',
#  'top',
#  'stand before',
#  'kill',
#  'waiting to go',
#  'jump to left to climb',
#  'running and jumping for',
#  'revive',
#  'walking to',
#  'standing',
#  'chase',
#  'move off',
#  'slid',
#  'jump to collect',
#  'keep going to',
#  'solidifying',
#  'saved from',
#  'slowly move',
#  'taken by',
#  'turn to right take',
#  'stand for',
#  'comes towards',
#  'cross',
#  'til',
#  'waits',
#  'start jumping up',
#  'climbs down',
#  'go by',
#  'climb into',
#  'climb over',
#  'slightly moved',
#  'pausing to avoid',
#  'to climb down',
#  'move to skull jump',
#  'to attacked and died',
#  'fell',
#  'clime on',
#  'try to avoid',
#  'stocked',
#  'left behind',
#  'do not go to',
#  'using',
#  'reappear',
#  'jump left',
#  'go left and stop',
#  'are walking for',
#  'slightly move left toward',
#  'move left jump',
#  'go across',
#  'stop on',
#  'go toward',
#  'move left and downwards',
#  'happens',
#  'going left',
#  'stand under',
#  'jump using',
#  'is waiting to cross',
#  'walking under',
#  'to disappear for',
#  'open',
#  'move under',
#  'come from',
#  'felt',
#  'do not move',
#  'jumping to',
#  'move to left',
#  'are blocked from',
#  'is jumping and moving',
#  'reappears then go',
#  'waiting to ladder',
#  'walking for',
#  'start climbing up',
#  'goes to',
#  'get',
#  'quickly move',
#  'wait on',
#  'goes past',
#  'waiting on',
#  'walk in',
#  'moved jump',
#  'rolls to',
#  'follow behind',
#  'slightly climb',
#  'jump then stuck',
#  'to pass by',
#  'need to time',
#  'jump to rope',
#  'is out',
#  'leap to',
#  'break',
#  'to take',
#  'clip to',
#  'walk off',
#  'stop beneath',
#  'go off',
#  'look upon',
#  'shimmy',
#  'following',
#  'runs',
#  'jump and running to',
#  'to move',
#  'jump on',
#  'use',
#  'going to go',
#  'pass',
#  'try to climb',
#  'again turn',
#  'falling',
#  'go then stop',
#  'are flashing',
#  'start scrolling',
#  'disappear to',
#  'lose',
#  'goes from',
#  'flicker',
#  'watch and walk',
#  'wait down',
#  'advance up',
#  'try to climb above',
#  'walk from',
#  'to fade',
#  'go between',
#  'jumping and walking for',
#  'to collect',
#  'goes towards',
#  'comes by',
#  'climb onto',
#  'heads',
#  'wait to reach',
#  'go to left',
#  'are hidden',
#  'stop scrolling',
#  'go left jumping over',
#  'stop between',
#  'slowly make',
#  'jump towards',
#  'immediately climb down',
#  'go left underneath',
#  'climbing towards',
#  'injuring by',
#  'move for',
#  'walk under',
#  'go left and bite by',
#  'stay put then move',
#  'waiting and standing on',
#  'hop',
#  'wait and jump',
#  'not moved',
#  ...}

# %%
'stay' in verb_phrase_set
# Out:
# True

# %%
'move' in verb_phrase_set
# Out:
# True

# %%
# Store the action phrases 
with open('train_data/action_phrase_chunk_set.pkl', 'wb') as f:
    pickle.dump(verb_phrase_set, f)

# %% [markdown]
# ## Analyse Noun phrase

# %%
NOUN_PATTERNS = [
    ['PP', 'NP'],
    ['NP', 'PP'],
    ['NP'],
]

# %%
print(data[2880]['spell_correction_txt'])
print(data[2880]['phrase_chunking_sentence'])
print(data[2880]['phrase_chunking_tag'])
# Out:
# wait for the steps on the right to appear , then climb and into the next area .
# ['wait', 'for', 'the steps', 'on', 'the right', 'to appear', 'climb', 'and', 'into', 'the next area']
# ['VP', 'PP', 'NP', 'PP', 'NP', 'VP', 'VP', 'PP', 'PP', 'NP']

# %%
find_pattern(ACTION_PATTERNS,
             data[2880]['phrase_chunking_sentence'],
             data[2880]['phrase_chunking_tag'])
# Out:
# ([['wait', 'for'], ['climb', 'and'], ['to appear']],
#  [['VP', 'PP'], ['VP', 'PP'], ['VP']])

# %%
# collect all the verb phrase in the training data 
noun_phrase_set = set()

for key, val in data.items():
    phrase_arr, _ = find_pattern(NOUN_PATTERNS,
                                 val['phrase_chunking_sentence'],
                                 val['phrase_chunking_tag'])
    
    val['noun_phrase_arr'] = []
    # process the phrase_arr
    for phrase in phrase_arr:
        str_phrase = ' '.join(phrase)
        val['noun_phrase_arr'].append(str_phrase)
        noun_phrase_set.add(str_phrase)

# %%
len(noun_phrase_set)
# Out:
# 1556

# %%
noun_phrase_set
# Out:
# {'screen',
#  'a left',
#  'the rope to the left',
#  'little jump',
#  'one screen to the next',
#  'fire',
#  'skull rolling',
#  'hope over snakes',
#  'the ladder over the checked bridge',
#  'the skulls in the next room',
#  'one step down the ladder',
#  'ladder upside',
#  'the another location',
#  'that object',
#  '6 times',
#  'this person ladder jump',
#  'screens',
#  'jump and pickup ladder',
#  'ladder to original point',
#  'the first blue lines on the background',
#  'right side and death',
#  'the next room on the left',
#  'the ladder on the bottom',
#  'field',
#  'the creature on the left',
#  '5 steps to the right',
#  'the next level with the ladder',
#  'two snakes to the left',
#  'just little move to right side',
#  'ledge before bridge',
#  'next zone',
#  'the half way point on the ladder',
#  'the skelton',
#  'all the way up the ladder',
#  'the gold hammer',
#  '5 steps to the left',
#  'the leftwards',
#  'the dangerous rays',
#  'the right toward the next wall',
#  'hesitation',
#  'the skeleton head',
#  'the moving platform',
#  '3 steps',
#  'rope to the top',
#  'wait',
#  'no way',
#  'left to right',
#  'the hammer',
#  'the side',
#  'this',
#  'view',
#  'the ladder on standing',
#  'two times break',
#  'the purple platform to your right',
#  'the narrow long line',
#  'your level with the snake',
#  'the box',
#  'the blurry lines',
#  'electric lines',
#  'the first line of electric and pause',
#  'jump to the right',
#  'the next platform',
#  'the life',
#  'a jump to the right',
#  'the upper edge',
#  'the correct time ladder',
#  'it to the left horizontal line',
#  'place',
#  'the pad',
#  'the room with the snakes',
#  'the middle of the ladder',
#  'half way',
#  'the right until the end',
#  'the gold coin by little jump',
#  'one second',
#  'a few rungs',
#  'the background stripes',
#  'room with ladder',
#  'the ladder upside skull',
#  'the trap',
#  'the rope to the floor',
#  'the left platform',
#  'the right into the black part',
#  'go to the other location',
#  'electric wall',
#  'a few steps down ladder',
#  'other side ladder',
#  '2 steps',
#  'the steps for four times',
#  'side',
#  'cross between the laser ray',
#  'go to the top place',
#  'a few steps up the ladder',
#  'a little bit more',
#  'the small ladder',
#  'the coin on the left',
#  'all the way down the ladder',
#  'our hero',
#  'the fading platforms',
#  'the spider passes',
#  'string on left',
#  'the snake to the right',
#  'the electric circuit',
#  'the flaming torch',
#  'ladder underside',
#  'the goal',
#  'the ledge on the left',
#  'the next zone',
#  'three times toward the next area',
#  'the up ladder',
#  'the right of the gem',
#  'the door to your right',
#  'the ladder into the next world',
#  'the upside',
#  'that of the snake',
#  'the string or thread',
#  'down ladder to the bottom',
#  'the bottom',
#  'barrier columns on your right',
#  'next level',
#  'left and climb ladder',
#  'the reach',
#  'st stage to and stage',
#  'the blue floor',
#  'the key by little jump',
#  'exit ladder and face right',
#  'just one step towards left side',
#  'the ladders',
#  'the flame',
#  'the the ground',
#  'the ladder to the ground',
#  '1 more step to the right',
#  'golden key collection',
#  'ladder to lower level',
#  'the run',
#  'the ladder to the bottom',
#  'jump from the ladder',
#  'little move',
#  'the vertical line',
#  'white rope',
#  'the rope to safety',
#  'your heel',
#  'the right room',
#  'little move to left side',
#  'this running',
#  '1 big step',
#  'the vanishing platforms',
#  'the move to the right',
#  'move step of the upstairs',
#  'the two snakes',
#  'two snakes',
#  'purple pole to top',
#  '5 rungs of the blue ladder',
#  'the barrier',
#  'the left room up the ladder',
#  'three time',
#  'the ladder to the right edge',
#  'slightly left walk',
#  'the green enemy',
#  'the flickering lights',
#  'the right into the next room',
#  'the room',
#  'the beam',
#  'that place',
#  'the jump to the right',
#  'the ledge onto the rope',
#  'right and jumping',
#  'the second snake',
#  'other side',
#  'the ladder in the bottom middle',
#  'the step',
#  'the rope in the center',
#  'the spider',
#  'the ladder to the right',
#  'a little to the left',
#  '3 more steps to the right',
#  'a little bit to the right',
#  'the white lines',
#  'focus',
#  'the blinking electric waves',
#  'step left',
#  'ladder in the center',
#  'ladder two rungs',
#  'skip ladder',
#  '1 jump',
#  'new zone',
#  'cross between the laser beam',
#  'string',
#  'the danger way',
#  'ladder until on the ground',
#  'the fast run',
#  'rays',
#  '5 times',
#  'bottom of ladder',
#  'the ladder on next level',
#  'the jewel',
#  'the pole',
#  'new screen',
#  'the blue squiggly floor',
#  'jumps',
#  'this golden key collection',
#  'the ladder for visibility',
#  'the ledge',
#  'the center platform',
#  'the ladder above the bug',
#  'right room',
#  'the force fields to your left',
#  'the item on the left',
#  'use ladder',
#  'ladder down this light button',
#  'left 3 steps',
#  'vertical line',
#  'the purple room',
#  'the wakefield',
#  'the opposite edge',
#  'skull',
#  'this running to next ladder spider',
#  'coin',
#  'a few stops',
#  'another area',
#  'the person',
#  'the left',
#  'the middle of ladder',
#  'the ladder before spider',
#  'little move after laser beam',
#  'two steps left pause',
#  'front of the barrier',
#  'the waves',
#  'next clear area',
#  'ladder pass floor',
#  'the right in the fully black room',
#  'the endow',
#  'the squiggly lines',
#  'move slight down the ladder',
#  'three steps to the right',
#  'the the right climb',
#  'the two rooms',
#  'the screen',
#  'the bar',
#  'a little bit to the left',
#  'a few steps in front',
#  'the ground',
#  'ward',
#  'the electrical field',
#  'the poll',
#  '1 st level',
#  'the ladder into the bug',
#  '4 steps to the left',
#  'the left into the lines',
#  'the partly half of the ladder',
#  'a couple of steps',
#  'the middle stick down skull',
#  'the electric buzz',
#  'the wall',
#  'the top ledge',
#  'the poles',
#  'a bit',
#  'killer',
#  'the blue room',
#  'a screen',
#  'hazardous columns',
#  'this and laser climb',
#  'floor level of snakes',
#  'the hanging pole',
#  'a small step towards the barrier',
#  'guy',
#  'the edge',
#  'a height',
#  'top from ladder',
#  'the rolling skull',
#  'the next location',
#  'the trench',
#  'the bridge to the left',
#  'left to right walk',
#  'white bars',
#  'the danger sign',
#  'out touch',
#  'your best',
#  'the downside',
#  'center of screen',
#  'the second time',
#  'the ladder below the skulls',
#  'prize',
#  'the ladder into the lava',
#  'both snakes',
#  'the golden key',
#  'the bug passes',
#  'the blinking stair',
#  'the man middle of ladder',
#  'ladder to ground',
#  'ledge',
#  'the left with the skulls',
#  'the ladder for the spider',
#  'three steps',
#  'jump',
#  'anything',
#  'walls',
#  'sword',
#  'the ladder before crab catches',
#  'the first 2 and jump',
#  'the ladder on climb',
#  'a bit on the rope',
#  'top of purple pole',
#  'the right voiding barriers',
#  'second pair of barriers',
#  'the lines to the left',
#  'the ladder into the purple room',
#  'power supply',
#  'a bit more',
#  'the right into an bug',
#  'a jump to the left',
#  'jumping',
#  'left side',
#  'the flashing poles',
#  'the right to the left',
#  'the nice place',
#  'the key power',
#  'floor',
#  'waiting',
#  'the floating ledges on the right',
#  'the jump over the snake',
#  'next stage',
#  'the room in the right',
#  'the right towards the ladder',
#  'step to right',
#  'two steps to the right',
#  'the floating skulls',
#  'ones',
#  'ladder jump and jump',
#  'the ledge on the right',
#  'half',
#  'the rope in the middle',
#  'obstacles',
#  'ladder thisdwon other side ladder upside and spider',
#  'right jump',
#  'the snakes to your left',
#  'a floor',
#  'lines',
#  'ground portion of ladder',
#  'the vertical lines',
#  'right by walk',
#  'the next room in the new room',
#  'a ladder',
#  'the floating ledge',
#  'step towards barrier',
#  'the left over the snakes',
#  'the platforms',
#  'your way along the bridge',
#  'game',
#  'person',
#  'the ladder past the snake',
#  'the rope to the ground',
#  'the help of ladder',
#  'rope to platform',
#  'the solid brick',
#  'a little',
#  'climb ladder',
#  'the bridge over the lava',
#  'the path',
#  'moves to the right',
#  '1 small step',
#  'rolling skull',
#  'three times to the blue lines',
#  'the connecting blocks',
#  'straight',
#  'platform on the right',
#  'vertical lines',
#  'climb rope',
#  'a snake',
#  'letter',
#  'the playing',
#  'the snake into the room',
#  'the lines track',
#  'the right to the next room',
#  'success',
#  'upwards',
#  'big ladder',
#  'floating skeleton heads',
#  'little move in downside',
#  'the two walls',
#  'moving horizontal line to the right',
#  'the top of the purple room',
#  'ladder to first level',
#  'the columns',
#  'grab purple pole',
#  'stationary long bar',
#  'the left over the skull',
#  'the same place',
#  'the dots',
#  'the skeletons',
#  'the snake other side',
#  'the pole jump',
#  'middle of steak and right side ladder',
#  'second time',
#  'the slap',
#  'just little move in laser beam',
#  'the barriers',
#  'the objects',
#  'the obstacles',
#  'the purple rope',
#  'the next room on the right',
#  'the green ladder',
#  'the right stop before next column',
#  'the buzzing',
#  'the end of the screen',
#  'one long jump',
#  'the stick',
#  'the moving bar',
#  'the horizontal stripes',
#  'left into the next area',
#  'five times to the ledge',
#  'the gold coin',
#  'the reward',
#  'left side rope',
#  'the bug to the left',
#  'the bridge and jump',
#  'now',
#  'the left towards the ladder',
#  'a little bit down the ladder',
#  'the key to the left',
#  'the ladder on your left',
#  'upside by ladder',
#  'the right of the ladder',
#  'the top of the ledge',
#  'a little bit toward the ladder',
#  'the left of the ladder',
#  'this step',
#  'enemy',
#  'slights',
#  'the skull',
#  'steps',
#  'a little bit',
#  'the blue dashes',
#  'the left to the edge',
#  'the other ladder',
#  'little front',
#  'the white skull',
#  'the skull on the left',
#  'left jump to the rope',
#  'them at right time',
#  'go',
#  'shock columns',
#  'hold of the rope',
#  'the flashing lights',
#  'visible the bridge',
#  'walks',
#  'spawn',
#  'place on the ladder',
#  'the lava pit',
#  'the middle platform to the left',
#  'item',
#  'the imaginary ground',
#  'the right stop',
#  'slow walking',
#  'skull jump ladder upside',
#  'one rope',
#  'a moving jump',
#  'walk to the right',
#  'the ladder in the next room',
#  'the previous room',
#  'the electric shock',
#  'the right into the lines',
#  'what',
#  'the far right edge',
#  'the ball',
#  'the door',
#  'jump across the bridge',
#  'key by little jump',
#  'edge',
#  'the snake on the left',
#  'wavy lines',
#  'this laser',
#  'snake and climb ladder',
#  'the wire',
#  'right and climb ladder',
#  'the flashing ledges',
#  'your way up the ladder',
#  'small steps to the left',
#  'the one cross',
#  'the down place',
#  'the platform',
#  'ghost',
#  'one more possible',
#  'your right',
#  'each corner of the figure',
#  'the bride',
#  'the moving dashes',
#  'hop to the left',
#  'the floor',
#  'stairs',
#  '1 walk',
#  'gold coin',
#  'other snake',
#  'a barrier',
#  'flashing lights',
#  'the right side of the landing',
#  'the right pole',
#  'your way to the right',
#  'onside ladder',
#  'little move for this ladder',
#  'land',
#  'the center of the room',
#  'the end of it',
#  'a jump over the skull',
#  'the void',
#  'skilled',
#  'purple hanging pole',
#  'beams',
#  'the beam side',
#  'the right edge of the screen',
#  'time',
#  'the ladder onto the next level',
#  'clip down the ladder',
#  'the white rope',
#  'leaf',
#  'it to the horizontal line',
#  'the snack',
#  'the rising lines',
#  'the room on the right',
#  '4 times',
#  'a key',
#  'two times',
#  'your side',
#  'the chain',
#  'the next level to upstairs',
#  'two jump',
#  'the upstairs',
#  'the torch',
#  'man',
#  'one right leg',
#  'the challenge',
#  'the monster',
#  'top of the bug',
#  'the stair',
#  'the platform in the middle',
#  'this away ladder',
#  'snake on left',
#  'the next screen',
#  'the laser rays',
#  'left and right side',
#  'claim',
#  'stand',
#  'your way on the ladder',
#  'snake',
#  'two small steps to the left',
#  'the left of the map',
#  'slightly walk',
#  'the right , climb ladder',
#  'left step towards barrier',
#  'the new zone',
#  'obstruction',
#  'two step to right',
#  'the left rope',
#  'the first electricity',
#  'the left to the next room',
#  'this just move',
#  'the ladder to the blue room',
#  'right time',
#  'the creature',
#  'upstairs to that aim',
#  'the gem',
#  'continuous jump over upside',
#  'your self',
#  'electrical fence',
#  'the top of pole',
#  'upside and anotherlocation',
#  'one rung',
#  'left jump',
#  'the blue waves',
#  'a',
#  'jump to upside',
#  'the water crater',
#  'fast search',
#  'the line of single dashes',
#  'another place with ladder',
#  'a move',
#  'the laser bridge',
#  'the next side',
#  'the top platform',
#  'little place',
#  'green spider',
#  'downside',
#  'the middle of the room',
#  'form ladder',
#  'right stop',
#  'the ladder wait crab',
#  'the flickering bars',
#  'the right end',
#  'the right place',
#  'the top middle ledge',
#  'wait and go',
#  'the next bars',
#  'the bottom of the rope',
#  'the left edge',
#  'the room on the left',
#  'the side of left',
#  'the far right side of the room',
#  'the right barrier',
#  'the beams from the ground',
#  'the fading columns of electricity',
#  'the item',
#  'bars',
#  'the middle of the bridge',
#  'the height of 1 hat',
#  'little up',
#  'the force field',
#  'shuffle in place',
#  'ladder to old zone',
#  'the platform to the left',
#  'them',
#  'the right into the next area',
#  'laser beam disappear center point',
#  'current screen',
#  'the water level',
#  'the ladder to the next area',
#  'snake towards the ladder',
#  'the left side of the screen',
#  'fence',
#  'club up the ladder',
#  'the rope and right walk',
#  'done walk',
#  'next step',
#  'the right toward the ladder',
#  '3 steps to the right stop',
#  'a same place',
#  'spider passes',
#  'the coin from the left turn',
#  'the platform to the other side',
#  'green creature',
#  '3 times on the ladder',
#  'ladder to new zone',
#  'right and wait',
#  'laser',
#  'a right into the next area',
#  'jump over the white skull',
#  'the surroundings',
#  'animal',
#  'top of stairs',
#  'the ladder to the purple room',
#  'barrier light',
#  'ladder to the left',
#  'one short step',
#  'top of pole',
#  'little move to upside',
#  'barrier',
#  'ord columns',
#  'latter',
#  'the gate',
#  'the ladder into the next room',
#  'ladder',
#  'the platforms to the right',
#  'jumps to the right',
#  'water',
#  'few minutes',
#  'a sword',
#  'the horizontal lines barrier',
#  'almost half way',
#  'the ladder to the platform',
#  'walk towards left',
#  'the second set',
#  'one left step',
#  'the next room down the ladder',
#  'another one',
#  'right side in laser beams',
#  'the flashing lines',
#  '3 times',
#  'the movement of rays',
#  'the left on the blue lines',
#  'the space',
#  'the ladder',
#  'snakes on either side',
#  'it',
#  'the sword',
#  'a left down the rope',
#  'the right jump',
#  'the ladder into the new zone',
#  'the human skull and go',
#  'the edge of the pit',
#  'the previous screen',
#  'the flickering lines to the right',
#  'the quicksand',
#  'the movement of the creature',
#  'the next area toward the ladder',
#  'ladder in another location',
#  '3 steps past the ladder',
#  'each side',
#  'the right edge',
#  'the doors',
#  'the next end',
#  '3 more times on the squiggle bricks',
#  'right 3 steps',
#  'a few more steps',
#  'the top of the rope',
#  'upside another location',
#  'down side',
#  'the banner',
#  'the rays',
#  'the laser',
#  'the top of the ladder',
#  'it to the left',
#  'one',
#  'your head',
#  'the purple pole',
#  'the vibration',
#  'the white pole',
#  'the left into the next area',
#  'crab',
#  'four times',
#  'tiny block',
#  'the tumbling skull',
#  'leaser beam',
#  'the floor de',
#  'the devil crossing',
#  'next location',
#  'the platform onto the yellow pole',
#  'laser beams',
#  'step to the right',
#  'the right on the blue squiggly line',
#  'the two skulls down the ladder',
#  'slider',
#  'one step to the right',
#  'right side of screen',
#  'the space between the rising horizontal lines',
#  'the lowest tier platform',
#  'few steps',
#  'the next area to the left',
#  'the right past the flickering lines',
#  'monster',
#  'small steps',
#  'waiting person',
#  'the force fields',
#  'a ledge',
#  'the leftside',
#  'the ladder to the next screen',
#  'jump and touch snake',
#  'two seconds',
#  'the stripes',
#  'the key jump',
#  'laser climb',
#  'this screen',
#  'cross',
#  'the fire',
#  'the green spider',
#  'the yellow icon',
#  'ladder two rungs below ground level',
#  'the blue lines',
#  'the two lines',
#  'your way to the rope',
#  'front side snake coming ladder',
#  'snake to the ladder',
#  'right and go',
#  'the ladder to the next platform',
#  'half way to the ladder',
#  'just one jump',
#  'the last area',
#  'golden key collect',
#  'the skull to the right',
#  'jump from the pole',
#  'the buzzsaw',
#  'the bridge to the right',
#  'a screen with wavy blue lines',
#  'just little move to left side',
#  'the ladder to the left',
#  'the',
#  'one ladder rung',
#  'the other snake',
#  'fails',
#  'the ladder for a bit',
#  'climb down the ladder',
#  'the solid platform',
#  'the correct time',
#  'your way',
#  'down ladder turn left jump over snake',
#  'the right jump on the rope',
#  'left & jump',
#  'ladder for spider',
#  'first floor',
#  'bottom',
#  'stepson',
#  'next screen',
#  'no any action',
#  'the right wall',
#  'town',
#  'the middle ledge',
#  'nothing',
#  'the lines',
#  'the green',
#  'a few steps to the left',
#  'the top of the green ladder',
#  'step jump on the ladder',
#  'right side of room',
#  'front of the first set',
#  'left turn',
#  'platform',
#  'the wave',
#  'escape from the snack',
#  'it to the right side',
#  'white lines',
#  'your place',
#  'the purple',
#  'no movement',
#  'the left toward the ladder',
#  'two rungs down the ladder',
#  'the lasers',
#  'the ladder onto the brick level',
#  'the ladder to the next level',
#  'a few steps towards left',
#  'the purple line',
#  'the skulls to the right',
#  'the yellow pole',
#  'a quarter step',
#  'a few small steps to the right',
#  'another level',
#  '2 more steps to the right',
#  'the rope to the right',
#  'the floating flashing bridge to the right',
#  'barriers',
#  'stair',
#  'the pillar',
#  'the rope to the platform',
#  'the life edge',
#  'the human skull',
#  'don',
#  '1 second',
#  'new one',
#  'the upside on ladder',
#  'a step towards barrier',
#  'four steps',
#  'the right of the screen',
#  'a minute in the middle',
#  'the pattern to the forcefield',
#  'two steps up the ladder',
#  'the left under the skulls',
#  'rope jump',
#  'a split second',
#  'opposite side',
#  'inch',
#  'the disappearing floor',
#  'the left ledge',
#  'the ruby',
#  'the pit',
#  'the level',
#  'front',
#  'the ladder to the top',
#  'the thin purple stick',
#  'the ledges to the top',
#  'safe zone',
#  'a different area',
#  'the first floor',
#  'the white string',
#  'the left jump over snake',
#  'other side gong to person',
#  'the draw bridge',
#  'this person ladder upside',
#  'flame',
#  'the top middle platform to the left',
#  'a couple of times',
#  'a little to the right turn',
#  'the another side',
#  'the ladder by half a rung',
#  'the black room',
#  'two times to the left',
#  'the bug',
#  'he',
#  'a while',
#  'top of the snake',
#  'creature',
#  'the mote',
#  'the ladder in the blue world',
#  '3 times after two step',
#  'ladder to another new zone',
#  'the reach to the goal',
#  'the yellow pole to the left',
#  'the right onto the next screen',
#  'pipe',
#  'the left and down the ladder',
#  'ladder for go',
#  'the all',
#  'the disappearing lines',
#  'left little jump over the snake',
#  'a jump',
#  'temporary steps',
#  'force field',
#  'the left to the room',
#  'the land',
#  'the laser ray',
#  'the right toward the key',
#  'the while',
#  'the upside by ladder',
#  'a little up the latter',
#  'upstairs',
#  'key',
#  'the end',
#  'a few more',
#  'the top of ladder',
#  'running and jumping after that',
#  'life',
#  'cross across the laser beam',
#  'a token',
#  'then ladder',
#  'the left side',
#  'the middle ledge to the rope',
#  'the left of the flashing lights',
#  'walk',
#  'left and jump',
#  'ladder to next screen',
#  'the hero',
#  'no next level',
#  'skeleton head',
#  'the hanging purple rod',
#  'the strips',
#  'the steps on the right side',
#  'the fading platform',
#  'the nearest rail',
#  'the climb',
#  'the power',
#  'the wavy lines',
#  'the ladder into the next screen',
#  'the end of screen',
#  'ladder and zone end',
#  'the other side spider',
#  'the next set of lines',
#  'a step to the right',
#  'right and laser beam',
#  'all the way to the left',
#  'some wavy lines',
#  'the beam light',
#  'wait few minutes',
#  'jump for the sword',
#  'the snakes',
#  'the down ladder',
#  'another location',
#  'the bottom floor',
#  'the force',
#  'the right across the force',
#  'the bridge',
#  'the right climb down the ladder',
#  'wall',
#  'two then down rest of steps',
#  'the electricity',
#  'the left into the blue room',
#  'this jump',
#  'right and jump',
#  'end of solid ledge',
#  'a little past the ladder',
#  'electric walls',
#  'little time near the laser beam',
#  'playing',
#  'the right time',
#  'one long step',
#  'jump on the platform',
#  'come downside',
#  'some jumps',
#  'the object',
#  'the right down the head',
#  'insect',
#  'the right over the monster',
#  'go to the upside',
#  'your way to the left',
#  'the steps on the right',
#  'itself',
#  'the down the ladder',
#  'the second step',
#  'the middle small ledge',
#  'left side in laser beam',
#  'fast move',
#  'the right to the edge',
#  'all the way to the right',
#  'this person jump and rope',
#  'climbs above the ladder',
#  'one snake',
#  'a right',
#  'clear area',
#  'the latter',
#  'lets',
#  'the middle of the barriers',
#  'next platform',
#  'the right',
#  'this laser light',
#  'only two steps',
#  'the ladder between the two rooms',
#  'sometime',
#  'those lasers',
#  'the down button',
#  'the ledge above the rope',
#  'the lines on the left',
#  'the platform toward the right side',
#  'the left through the lasers',
#  'the edge of the cliff',
#  'the up and fast run',
#  'the skull to the left',
#  'a bit at the ladder',
#  'your in front',
#  'the line on the left',
#  'a step',
#  'the person downside',
#  'the ladder to the middle',
#  'skelton game',
#  'the snake',
#  'three times towards ladder',
#  ...}

# %%
# Store the noun phrases 
with open('train_data/noun_phrase_chunk_set.pkl', 'wb') as f:
    pickle.dump(noun_phrase_set, f)

# %% [markdown]
# ## manual spell correction and sent emb reencoding
# ### Some wrong phrase correct them first before replacing
# 1. 'claim" -> 'climb'
# 2. 'club' -> 'climb'
# 3. 'done' -> 'do not'
# 4. 'clip' -> 'climb'
# 5. 'clumping' -> 'climbing'
# 6. 'clime' -> 'climb'
# 7. 'hope' -> 'hop'
# 8. 'toe' -> 'to'
# 9. 'endow' -> 'end'
# 10. 'latter' -> 'ladder'
# 11. 'bride' -> 'bridge'
# 12. 'leaser' -> 'laser'
# 13. 'later' -> 'ladder'
# 14. 'leaf' -> 'left'
# 15. 'snack' -> 'snake'
# 16. 'rob' -> 'rope'
# 17. "don' -> 'do not'
# 18. 'article' -> 'verticle'
# 19. 'life edge' -> 'left edge'
# 20. 'done' -> 'do not'
# 21. 'ans' -> 'and'
# 22. 'skelton' -> 'skeleton'
# 23. 'skilled' -> 'skull'

# %% [markdown]
# ```
# dict: {<data_id> : {
#                     "spell_correction_txt": type->str,
#                     "embedding": type-> ndarray(768,),
#                     "phrase_chunking_sentence": type -> lst(str)
#                     "phrase_chunking_tag": type-> lst(str)
#                     }
#       }
# ```

# %%
word_correction_dict = {
    'claim' : 'climb',
    'club' : 'climb',
    'done' : "do not",
    'clip' : 'climb',
    'clumping': 'climbing',
    'clime' : 'climb',
    'hope' : 'hop',
    'toe': 'to',
    'endow': 'end',
    'latter' : 'ladder',
    'bride' : 'bridge',
    'leaser':'laser',
    'later' : 'ladder',
    'leaf':'left',
    'snack':'snake',
    'rob': 'rope',
    'don': 'do not',
    'article': 'verticle',
    'life edge' : 'left edge',
    'done' : 'do not',
    'ans' : "and",
    'skelton' : 'skeleton',
    'skilled' : 'skull'
}
def manual_correction(inputdata):

    for key, val in tqdm(inputdata.items()):
        output_sent = val['spell_correction_txt']
        for wrong_w, cor_w in word_correction_dict.items():
            o = replacewords(output_sent, wrong_w, cor_w)
            if o is not None:
                output_sent = o
        # we have the correct output_sent
        val['spell_correction_txt'] = output_sent
        val["embedding"]: convert_to_sentence_embedding(val['spell_correction_txt'])
        phrase_chunking_str, phrase_chunking_tag = convert_to_phrase_chunking(val['spell_correction_txt'])
        val["phrase_chunking_sentence"] = phrase_chunking_str
        val["phrase_chunking_tag"] = phrase_chunking_tag

# %%
manual_correction(data)
# Out:
# /tmp/ipykernel_4945/959488254.py:28: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for key, val in tqdm(inputdata.items()):
#   0%|          | 0/5655 [00:00<?, ?it/s]

# %% [markdown]
# ## Create and store negative examples

# %%
import random

# %%
# strategy, for each sentences, we randomly select one correct action / noun phrase
# swap with another action (1/1105) or noun (1/1578)
# furthermore, we create both action and noun polluted example (0.1M)
# so we will have the following structure
with open('./training_data/train_text_dict.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
print(data[0]["spell_correction_txt"])
print(data[0]["phrase_chunking_sentence"])
print(data[0]["phrase_chunking_tag"])
print(data[0]["verb_phrase_arr"])
print(data[0]["noun_phrase_arr"])
# Out:
# climb up the ladder until you reach the top of the purple room
# ['climb', 'up', 'the ladder', 'until', 'you', 'reach', 'the top', 'of', 'the purple room']
# ['VP', 'PP', 'NP', 'SBAR', 'NP', 'VP', 'NP', 'PP', 'NP']
# ['climb up', 'reach']
# ['up the ladder', 'of the purple room', 'you', 'the top']

# %%
data[0]["spell_correction_txt"].index(data[0]["verb_phrase_arr"][1])
# Out:
# 30

# %% [markdown]
# ```
# dict: {<data_id> : {
#                     "spell_correction_txt": type->str,
#                     "embedding": type-> ndarray(768,),
#                     "phrase_chunking_sentence": type -> lst(str),
#                     "phrase_chunking_tag": type-> lst(str),
#                     'verb_phrase_arr': lst(str)
#                     'noun_phrase_arr': lst(str)
#                     "action_polluted_embedding": type-> lst(ndarray(768,)),
#                     "noun_polluted_embedding": type-> lst(ndarray(768,)),
#                     "both_polluted_embedding": type-> lst(ndarray(768,)),
#                     }
#       }
# ```

# %%
# test
replacewords(' '.join(data[0]["phrase_chunking_sentence"]), data[0]["verb_phrase_arr"][1], "collide with")
# Out:
# 'climb up the ladder until you collide with the top of the purple room'

# %%
model
# Out:
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 512, 'do_lower_case': False}) with Transformer model: T5EncoderModel
#   (1): Pooling({'word_embedding_dimension': 768, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False})
#   (2): Dense({'in_features': 1024, 'out_features': 768, 'bias': False, 'activation_function': 'torch.nn.modules.linear.Identity'})
#   (3): Normalize()
# )

# %%
# get hard negative dict
with open('action_phrase_hard_negative_dict.pkl', 'rb') as f:
    action_phrase_hard_negative_dict = pickle.load(f)
    
with open('noun_phrase_hard_negative_dict.pkl', 'rb') as f:
    noun_phrase_hard_negative_dict = pickle.load(f)

# %%
def create_manual_polluted_embeddings(original_text, the_phrase_arr, hard_neg_dict, embedding_model):
    # output: lst(embedding), size = len(verb_phrase_set) - e
    if len(the_phrase_arr) == 0:
        return None
    output_lst = []
    for p in the_phrase_arr:
        hard_neg_phrase_arr = hard_neg_dict.get(p)
        if hard_neg_phrase_arr is None or hard_neg_phrase_arr == []:
            continue 
#         print('phrase', p, 'hard neg', hard_neg_phrase_arr)
        for hard_neg_p in hard_neg_phrase_arr:
            # replace
            polluted_sent = replacewords(original_text, p, hard_neg_p)
            if polluted_sent is not None:
                # calculate emb 
#                 print(polluted_sent)
                emb = embedding_model.encode(polluted_sent)
                output_lst.append(emb)
        
    if output_lst == []:
        return None
    else:
        return output_lst
    


THE_SIZE = 500

def create_polluted_embeddings(original_text, the_phrase_arr, the_phrase_set, embedding_model):
    # output: lst(embedding), size = len(verb_phrase_set) - e
    if len(the_phrase_arr) == 0:
        return None
    output_lst = np.zeros((THE_SIZE, SEN_EMB_DIM), dtype=np.float32)
    for ind in tqdm(range(THE_SIZE), leave=False):
        # choose one original phrase
        old_phrase = random.choice(the_phrase_arr)
        phrase = random.choice(tuple(the_phrase_set))
        if phrase == old_phrase:
            continue 
        new_sent = replacewords(original_text, old_phrase, phrase)
        # need the model to calculate embedding 
        emb = embedding_model.encode(new_sent)
        output_lst[ind] = emb
    
    return output_lst
        

def create_both_polluted_embeddings(original_text, action_phrase_arr, noun_phrase_arr,
                                    verb_phrase_set, noun_phrase_set, embedding_model):
    # output: lst(embedding),
    if len(action_phrase_arr) == 0 and len(noun_phrase_arr) == 0:
        return None

    output_lst = np.zeros((THE_SIZE//5, SEN_EMB_DIM), dtype=np.float32)
    
    for ind in tqdm(range(THE_SIZE//5), leave=False):
        old_verb_phrase = None
        old_noun_phrase = None
        if len(action_phrase_arr) > 0:
            old_verb_phrase = random.choice(action_phrase_arr)
        if len(noun_phrase_arr) > 0: 
            old_noun_phrase = random.choice(noun_phrase_arr)
        new_verb_phrase = random.choice(tuple(verb_phrase_set))
        new_noun_phrase = random.choice(tuple(noun_phrase_set))
        
        new_sent = original_text
        
        if old_verb_phrase is not None:
            new_sent = replacewords(new_sent, old_verb_phrase, new_verb_phrase)
        if old_noun_phrase is not None and old_noun_phrase in new_sent:
            new_sent = replacewords(new_sent, old_noun_phrase, new_noun_phrase)
        emb = embedding_model.encode(new_sent)
        
        output_lst[ind] = emb
    return output_lst

# %%
data[0]["spell_correction_txt"]
# Out:
# 'climb up the ladder until you reach the top of the purple room'

# %%
data[0]["verb_phrase_arr"]
# Out:
# ['climb up', 'reach']

# %%
action_phrase_hard_negative_dict.get('reach')
# Out:
# []

# %%
action_phrase_hard_negative_dict.get('climb up')
# Out:
# ['climb down', 'jump left', 'jump right']

# %%
# test
test_list = create_manual_polluted_embeddings(data[0]["spell_correction_txt"],
                                       data[0]["verb_phrase_arr"],
                                       action_phrase_hard_negative_dict,
                                       model) # type: ndarray

# %%
len(test_list)
# Out:
# 3

# %%
# add to the data dict
# target_ind = 2359
# count = 0
for key, val in tqdm(data.items()):
#     count += 1 
#     if count < target_ind:
#         continue 
    val['action_polluted_embedding'] = create_manual_polluted_embeddings(val["spell_correction_txt"],
                                                                 val["verb_phrase_arr"],
                                                                 action_phrase_hard_negative_dict,
                                                                 model)
    val['noun_polluted_embedding'] = create_manual_polluted_embeddings(val["spell_correction_txt"],
                                                                 val["noun_phrase_arr"],
                                                                 noun_phrase_hard_negative_dict,
                                                                 model)
    
#     val['both_polluted_embedding'] = create_both_polluted_embeddings(" ".join(val["phrase_chunking_sentence"]),
#                                                                      val["verb_phrase_arr"],
#                                                                      val["noun_phrase_arr"],
#                                                                      verb_phrase_set,
#                                                                      noun_phrase_set,
#                                                                      model
#                                                                     )
# Out:
# /tmp/ipykernel_3879963/3198850839.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for key, val in tqdm(data.items()):
#   0%|          | 0/6870 [00:00<?, ?it/s]

# %% [markdown]
# ## Save hard negative examples as pkl

# %%
with open('training_data/train_text_dict_hard_negatives.pkl', 'wb') as f:
    pickle.dump(data, f)
