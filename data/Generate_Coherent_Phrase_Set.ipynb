# %%
import numpy as np
import torch
import re
import pickle 
import os
from tqdm.notebook import tqdm
from scipy.spatial.distance import cosine
from sentence_transformers import SentenceTransformer
from functools import partial
from collections import OrderedDict
from itertools import islice
from random import shuffle
from IPython.display import clear_output
import time

# %%
model = SentenceTransformer('sentence-transformers/gtr-t5-xl')

# %%
training_instruction_path = "train_data/training_instruction_sen_emb_phrase_chunk.pkl"
with open(training_instruction_path, 'rb') as f:
    raw_instruction_dict = pickle.load(f) # key:data_id, val:{"spell_correction_txt","embedding":
                                                            # "phrase_chunking_sentence", "phrase_chunking_tag"}

# %% [markdown]
# ## Analyse verb phrase set

# %%
with open('train_data/action_phrase_chunk_set.pkl', 'rb') as f:
    verb_phrase_set = pickle.load(f)

# %%
verb_phrase_set
# Out:
# {'remain up',
#  'disappear',
#  'stand to',
#  'grabbing',
#  'just waiting',
#  'waiting and standing on',
#  'walk',
#  'to capture',
#  'view',
#  'jump before',
#  'slowly make',
#  'slightly climb down',
#  'jump across',
#  'disappear take',
#  'turn',
#  'keep walking',
#  'wait between',
#  'to catch',
#  'little move',
#  'to evade',
#  'step down',
#  'switches',
#  'stops',
#  'starting',
#  'stuck',
#  'try to go',
#  'face',
#  'try to move',
#  'going',
#  'return to',
#  'avoiding',
#  'twice going',
#  'talk',
#  'keep going',
#  'to give',
#  'getting bitten by',
#  'try to collect',
#  'jump towards',
#  'climbing up',
#  'go slightly left',
#  'climb into',
#  'go left jumping over',
#  'go jump across',
#  'stay out',
#  'is moving',
#  'stay on',
#  'to avoid getting hit',
#  'again take',
#  'to pass',
#  'jumping up',
#  'jump going',
#  'jump to rope',
#  'playing',
#  'go left move to ladder',
#  'go past',
#  'to move across',
#  'are',
#  'jump to grab',
#  'jumping to',
#  'slipped',
#  'walk from',
#  'left to ledge',
#  'move under',
#  'break',
#  'continue to walk to',
#  'running into',
#  'to avoid',
#  'spoiled',
#  'to cross over',
#  'again moved towards',
#  'proceed to',
#  'needed',
#  'stand in',
#  'quickly move',
#  'see',
#  'continue walking towards',
#  'again turn',
#  'take',
#  'stand over',
#  'are walking for',
#  'running for',
#  'go left stop at',
#  'move to advance to',
#  'jumping from',
#  'crosses',
#  'bounce',
#  'to fade',
#  'hops',
#  'grasp',
#  'go left into',
#  'go left towards',
#  'halt',
#  'go left and stop',
#  'left towards',
#  'start to go',
#  'standing and thinking for',
#  'claim up',
#  'forces',
#  'jump to catch',
#  'pushing',
#  'move left and jump',
#  'jump on',
#  'move left and downwards',
#  'getting',
#  'must climb up',
#  'move left jump',
#  'stay',
#  'leap to',
#  'clip to',
#  'stand at',
#  'step left',
#  'do not get',
#  'go by',
#  'again jump over',
#  'exit to',
#  'slightly stand',
#  'rope',
#  'stays',
#  'found',
#  'move to climb up',
#  'die on',
#  'let',
#  'going to',
#  'jump left',
#  'stop after',
#  'made',
#  'reaches',
#  'stop in',
#  'to using',
#  'do not move from',
#  'walk under',
#  'have',
#  'pause at',
#  'are near by',
#  'goes towards',
#  'going to go',
#  'land on',
#  'get down',
#  'head',
#  'keep jumping',
#  'gets',
#  'can go',
#  'escape to',
#  'dodging',
#  'miss',
#  'to skull',
#  'try to climb',
#  'screwed to',
#  'left to right walk',
#  'climb of',
#  'reappears then go',
#  'started',
#  'wait and go',
#  'die',
#  'stand between',
#  'do not cross over',
#  'flicker',
#  'pass',
#  'look upon',
#  'have to jump',
#  'run between',
#  'has passed',
#  'clear',
#  'jumping over',
#  'leaves',
#  'touched',
#  're',
#  'lands',
#  'reset',
#  'was standing in',
#  'must cross with',
#  'surfaces',
#  'jumps to',
#  'running to',
#  'rolling to',
#  'once move',
#  'get behind',
#  'was bitten by',
#  'past',
#  'kill',
#  'again climb down',
#  'left toward',
#  'are hidden',
#  'do not get afraid move',
#  'ladder',
#  'just climb',
#  'wait behind',
#  'continue left',
#  'to face',
#  'goes down',
#  'go with',
#  'to do',
#  'let over',
#  'slowly walking',
#  'going from',
#  'is jumping across',
#  'try to climb up',
#  'catch',
#  'go to left by',
#  'to be',
#  'walk down',
#  'wait for',
#  'running and climb upside',
#  'again slightly move towards',
#  'killed by',
#  'go through',
#  'to spawn on',
#  'jumped',
#  'ascend',
#  'follow',
#  'collects',
#  'repeat',
#  'move left to go to',
#  'go left jump over',
#  'swing on',
#  'just wait',
#  'shuffle on',
#  'to safeguard from',
#  'walking under',
#  'step over',
#  'fell',
#  'gets disappears',
#  'climbs to',
#  'check',
#  'was stop running',
#  'to left through',
#  'keep going to get to',
#  'do not jump',
#  'do not touch',
#  'turn left and jump',
#  'is going',
#  'continue walking',
#  'flash',
#  'slightly go',
#  'slide down',
#  'to cross to',
#  'falling',
#  'to left towards',
#  'to change',
#  'exit on',
#  'til',
#  'start walking',
#  'to meet',
#  'walk towards',
#  'will be stop',
#  'end on',
#  'to clip on',
#  'is showing',
#  'used for',
#  'step',
#  'once moving',
#  'drop onto',
#  'head left',
#  'splits and stop',
#  'left',
#  'moving toward',
#  'crossed',
#  'go left down',
#  'pause to let',
#  'go under',
#  'crossing',
#  'standing for',
#  'go slightly jump',
#  'slightly going',
#  'try to avoid',
#  'jump to go',
#  'stocked',
#  'do not go to',
#  'to start',
#  'is waiting to cross',
#  'go left get',
#  'try to climb above',
#  'go left avoiding',
#  'to solidify',
#  'to reappear',
#  'wait and cross',
#  'got struck',
#  'appear and walk over',
#  'walk on',
#  'face left on',
#  'start climbing up',
#  'will be',
#  'stand on',
#  'to lead',
#  'to climb up',
#  'club',
#  'collecting',
#  'make',
#  'stay put after',
#  'landing',
#  'stand for',
#  'climb then going',
#  'timing',
#  'drop from',
#  'touch',
#  'proceed',
#  'to materialize',
#  'left along',
#  'left observing',
#  'continue going',
#  'climb to',
#  'then stop',
#  'cautiously approach',
#  'left onto',
#  'wait to reach',
#  'cautiously avoiding',
#  'move left and past',
#  'to disappear before',
#  'go across',
#  'hang from',
#  'to drop',
#  'to down jump',
#  'continuing',
#  'walk over',
#  'touched on',
#  'stay above',
#  'moving to',
#  'stops coming',
#  'pause before',
#  'move left and jump over',
#  'move to left , halt and move',
#  'avoid touching',
#  'moving',
#  'to collect',
#  'briefly enter',
#  'collected',
#  'go straight',
#  'to spawn',
#  'pausing to avoid',
#  'done move',
#  'moving towards',
#  'jump to',
#  'climb upside',
#  'open',
#  'is out',
#  'are come to',
#  'move left take',
#  'grab onto',
#  'to get',
#  'descend',
#  'got escaped from',
#  'go left hopping',
#  'claim down',
#  'to attacked and died',
#  'get disintegrated by',
#  'positioned under',
#  'continue passed',
#  'left into',
#  'climb for',
#  'clip down',
#  'changes',
#  'pass under',
#  'disappear towards',
#  'get near',
#  'is not shining',
#  'slightly move towards',
#  'play',
#  'keep moving to',
#  'go into',
#  'chase',
#  'left over',
#  'climbing on',
#  'using',
#  'goes',
#  'is shown',
#  'stop',
#  'stop near',
#  'passes',
#  'to turn',
#  'jumping and walking for',
#  'getting to',
#  'running past',
#  'go slightly coming',
#  'walk to',
#  'start going down',
#  'follow behind',
#  'continue climbing up',
#  'run past',
#  'continue',
#  'walking',
#  'climb top',
#  'jump up',
#  'hitting',
#  'wait before',
#  'return after',
#  'going for',
#  'get out',
#  'shuffle down',
#  'nearing',
#  'returned',
#  'waiting in',
#  'to move',
#  'will walking and cross',
#  'climbs down',
#  'try crossing to',
#  'to climb down',
#  'is coming',
#  'make move to',
#  'switch between',
#  'go left jumping on',
#  'go off',
#  'was move to',
#  'fully climb',
#  'edge',
#  'go climb to',
#  'stopped',
#  'head up',
#  'injuring by',
#  'turn to face',
#  'perform',
#  'jump above',
#  'jump down',
#  'climb over',
#  'jumps',
#  'keep doing',
#  'continue to do',
#  'jump left onto',
#  'get into',
#  'are waiting for',
#  'slightly climb up',
#  'is',
#  'stop before',
#  'facing',
#  'get struck by',
#  'move into',
#  'jump in',
#  'appears at',
#  'using to ladder in',
#  'approach',
#  'reached',
#  'hover over',
#  'hop up',
#  'watching',
#  'run right while',
#  'waiting to ladder',
#  'running and walking for',
#  'to appear then run',
#  'to go up',
#  'blink to continue',
#  'getting caught',
#  'jump to climb',
#  'disappear before',
#  'stay fixed at',
#  'are go to try',
#  'coming',
#  'slightly follow',
#  'stay put',
#  'go toward',
#  'to collected',
#  'move slightly left',
#  'left and stop',
#  'down take',
#  'was',
#  'to get to',
#  'slightly walk',
#  'will jump on',
#  'go left for',
#  'runs',
#  'to stand',
#  'keep going left stop at',
#  'keep walking to',
#  'getting hit',
#  'stop and wait',
#  'moves',
#  'to take',
#  'appears then walk to',
#  'stopping before',
#  'turned',
#  'exit',
#  'watched to skull',
#  'appears run to',
#  'little wait to cross',
#  'walking for',
#  'pick',
#  'comes go',
#  'again move',
#  'go repeat',
#  'to raise',
#  'stop and watch for',
#  'running and jumping after',
#  'to disappear for',
#  'keep running',
#  'disappear repeat',
#  'move past',
#  'continue walking to',
#  'go slightly stop on',
#  'wait then move',
#  'stay to',
#  'to appear before',
#  'run on',
#  'came from',
#  'try to jump over',
#  'cross over',
#  'pause for',
#  'moving under',
#  'hop from',
#  'move upon',
#  'use',
#  'start to run',
#  'watch',
#  'letting',
#  'keep from',
#  'suddenly return',
#  'wait at',
#  'to hit',
#  'go to get',
#  'to walk',
#  'wait in',
#  'stopping',
#  'goes past',
#  'advance up',
#  'hit',
#  'crawl',
#  'went',
#  'repeat for',
#  'be',
#  'to enter',
#  'move left jumping',
#  'lose',
#  'move for',
#  'avoid hitting',
#  'stop between',
#  'once left',
#  'is near',
#  'reaching',
#  'grab',
#  'also running',
#  'again wait',
#  'clumping',
#  'climbs',
#  'move and stop',
#  'jump toward',
#  'go left and into',
#  'continue to',
#  'making',
#  'reappear',
#  'try',
#  'go left to',
#  'get hit',
#  'to come stand',
#  'are appearing and disappearing',
#  'turn to',
#  'using to rope',
#  'claim',
#  'do not cross',
#  'keep running to',
#  'jump and run',
#  'running and going for',
#  'do not move',
#  'waits',
#  'show',
#  'stop going',
#  'to stop moving',
#  'sitting',
#  'go left',
#  'slowly go',
#  'to appear on',
#  'to left',
#  'arriving towards',
#  'passed',
#  'go left jump',
#  'to disappear take',
#  'hop off',
#  'turn left',
#  'to jump over',
#  'climb and',
#  'to appear then jump to',
#  'going watching',
#  'running',
#  'time',
#  'disappear to',
#  'jump twice going',
#  'walk in',
#  'was running to',
#  'slightly moved',
#  'staying behind',
#  'stay fixed to',
#  'are showing',
#  'place',
#  'will die',
#  'heads',
#  'again go',
#  'shimmy',
#  'just walk',
#  'turn to right take',
#  'avoid hitting or touching',
#  'clime on',
#  'go left to barrier',
#  'walks to',
#  'watch for',
#  'disappear make',
#  'moved',
#  'turns to',
#  'not moved',
#  'shuffle to',
#  'hop on',
#  'shuffle',
#  'move left have',
#  'following',
#  'are jumping across',
#  'walk off',
#  'jump for',
#  'to cross',
#  'slightly climb',
#  'to pass below',
#  'will be going',
#  'passes by',
#  'hanging to',
#  'flies',
#  'go to',
#  'move behind',
#  'move toward',
#  'slightly jump',
#  'does not move',
#  'felt',
#  'to finish',
#  'to jump',
#  'hide between',
#  'left making',
#  'to bounce',
#  'again jump',
#  'hit with',
#  'getting electrocuted',
#  'go left past',
#  'proceed down',
#  'afterwards climbing',
#  'gets down',
#  'slowly running',
#  'to go into',
#  'will be stocked',
#  'unfortunately attack',
#  'clip',
#  'go left underneath',
#  'jumping for',
#  'left and ridden',
#  'slowly climb',
#  'die by',
#  'continue to go',
#  'jump and running to',
#  'slightly going to',
#  'come from',
#  'came',
#  'back down',
#  'hits',
#  'escaped to',
#  'top',
#  'wait on',
#  'back',
#  'continue toward',
#  'run through',
#  'stay let crab',
#  'wait and going',
#  'disappear going to',
#  'to pass before',
#  'hang on',
#  'jump then keep running',
#  'to retrieve',
#  'do',
#  'walk across',
#  'wait to jump over',
#  'hit and fall by',
#  'jump to left to climb',
#  'do not make',
#  'start climbing',
#  'go between',
#  'will be lost',
#  'climb off',
#  'turning',
#  'to disappear walk to',
#  'stop walk',
#  'again move towards',
#  'get on',
#  'move on',
#  'move to left and jump',
#  'try to hop over',
#  'get',
#  'stuck then climb up',
#  'wait and reach',
#  'to go from',
#  'jump past',
#  'jump using',
#  'try to cross',
#  'wait near',
#  'go to left',
#  'reach',
#  'struck',
#  'do not go',
#  'carefully watching',
#  'was walking by',
#  'to appear then step',
#  'running and felt',
#  'goes to',
#  'going jump',
#  'stop and wait before',
#  'jump into',
#  'coming to',
#  'jumping in',
#  'collect',
#  'left underneath',
#  'climb to move',
#  'to come',
#  'to go down',
#  'caught',
#  'wait',
#  'disappears walk',
#  'slowly move to',
#  'climb onto',
#  'happens',
#  'to past',
#  'climbing down',
#  'move to skull jump',
#  'climbing towards',
#  'wait over',
#  'appear and disappear',
#  'walks',
#  'appears walk across',
#  'do not try to cross',
#  'carefully wait for',
#  'quickly walk',
#  'walk past',
#  'run',
#  'head towards',
#  'climb above',
#  'left to',
#  'start jumping up',
#  'is left of',
#  'run in',
#  'create',
#  'jump to collect',
#  'escaped',
#  'bump into',
#  'stay for',
#  'move towards',
#  'cross to',
#  'stand towards',
#  'appears jump',
#  'keep heading',
#  'jumping onto',
#  'move left to',
#  'to grab',
#  'to left move',
#  'appear',
#  'are flashing',
#  'disappear go',
#  'wait to see',
#  'stay in',
#  'spawn',
#  'move to',
#  'to clear before',
#  'keep going to left',
#  'comes towards',
#  'to go',
#  'bump',
#  'jump from',
#  'jumping and running for',
#  'move with',
#  'appearing and disappearing',
#  'walking on',
#  'continue up',
#  'move to cross with',
#  'begin to jump over',
#  'run to',
#  'moved jump',
#  'face left',
#  'to pause',
#  'will cross',
#  'immediately climb down',
#  'to avoid getting shocked by',
#  'thinking for',
#  'watch and walk',
#  'slightly left',
#  'will be blocked by',
#  'taken by',
#  'comes',
#  'jump at',
#  'just going to',
#  'stop moving',
#  'being',
#  'are like',
#  'go slow',
#  'drop',
#  'stay put for',
#  'to clear',
#  'to avoid being hit by',
#  'escape',
#  'immediately go',
#  'is climbing from',
#  'are walking in',
#  'slowly move',
#  'gone',
#  'to stop and proceed',
#  'beware of',
#  'to complete',
#  'disappears into',
#  'walk for',
#  'collected with',
#  'move left wait',
#  'hanging',
#  'simply standing on',
#  'stops falling',
#  'continue climbing',
#  'clime',
#  'died',
#  'moving from',
#  'wait facing',
#  'watch and claim',
#  'dodge',
#  'hold',
#  'stay at',
#  'avoid',
#  'slightly move',
#  'solidifying',
#  'to stop',
#  'move down',
#  'touched stocked',
#  'will appear on',
#  'get off',
#  'moved to',
#  'jump and cross',
#  'cross',
#  'walk with',
#  'fall',
#  'hope onto',
#  'move left toward',
#  'is on',
#  'stand under',
#  'jumping and walking',
#  'then jump',
#  'walking to',
#  'hang',
#  'jump to left',
#  'affect',
#  'were to',
#  'move left waiting',
#  'wait to re spawn',
#  'stop and straight go',
#  'solidify',
#  'climb',
#  'has',
#  'go left under',
#  'are running for',
#  'step off',
#  'are come and using',
#  'remain on',
#  'go towards',
#  'hop onto',
#  'stand still watching',
#  'slowly running for',
#  'jump over',
#  'wait and move',
#  'was climb',
#  'shows',
#  'slightly jump after',
#  'waling and running for',
#  'are faded',
#  'got move',
#  'stay put then move',
#  'think for',
#  'lands in',
#  'move to go',
#  'hope',
#  'jump under',
#  'entering',
#  'to ladder',
#  'need to time',
#  'passing',
#  'walk and ladder',
#  'retrieve',
#  'are using',
#  'got',
#  'to rope',
#  'move in',
#  'go left passed',
#  'are gone',
#  'to escape',
#  'to be filled',
#  'come',
#  'fall jump up',
#  'move from',
#  'are above',
#  'wait to',
#  'is climbing',
#  'is walking',
#  'walks past',
#  'bite by',
#  'waiting for',
#  'can jump',
#  'to avoid getting bitten by',
#  'to be start',
#  'go left slow',
#  'return',
#  'waiting to go',
#  'keep climbing in',
#  'slowly left',
#  'walk toward',
#  'to climb',
#  'walk along',
#  'stand near',
#  'to be out',
#  'revive',
#  'move left',
#  'stop near by',
#  'look',
#  'jump off',
#  'go down',
#  'stop right before',
#  'little move in',
#  'slid',
#  'are standing',
#  'move left to jump',
#  'to become',
#  'sword',
#  'using and running',
#  'slightly move left toward',
#  'jump off going',
#  'moves to',
#  'stay beneath',
#  'stop walking',
#  'waiting on',
#  'stop beneath',
#  'stood',
#  'standing in',
#  'once going',
#  'wait down',
#  'gets disappear on',
#  'jump and catch',
#  'waiting to',
#  'rolling',
#  'are blocked from',
#  'go left and jump',
#  'to get on',
#  'to pick',
#  'to pass by',
#  'followed by',
#  'jump whilst',
#  'are let down',
#  'little left',
#  'jump onto',
#  'pause',
#  'do not do',
#  'keep moving',
#  'jumping and catching',
#  'climb on',
#  'stand',
#  'come to',
#  'reaching to',
#  'walk up',
#  'to bitten',
#  'left by',
#  'go left toward',
#  'stuck then climb',
#  'stay hanging',
#  'stop at',
#  'go toe',
#  'walk into',
#  'go to climb',
#  'comes by',
#  'jumped over',
#  'stop scrolling',
#  'break through',
#  'reappears',
#  'to stop blinking',
#  'to get down',
#  'pop',
#  'to get onto',
#  'are on',
#  'to right see',
#  'go passed',
#  'to appear',
#  'down and running',
#  'move off',
#  'walk by',
#  'jump to get',
#  'stand before',
#  'stop climbing',
#  'go above',
#  'cautiously descend',
#  'falling from',
#  'start scrolling',
#  'turn on',
#  'to hop over',
#  'appears walk to',
#  'to walk into',
#  'stopping between',
#  'comes on',
#  'jump then stuck',
#  'go left jumping',
#  'waiting and going to',
#  'have disappear',
#  'goes from',
#  'go left and stop between',
#  'approaching',
#  'turn and face',
#  'go left watching',
#  'proceed to jump',
#  'continue going down',
#  'jump after',
#  'is jumping and moving',
#  'are not shining',
#  'to snake',
#  ...}

# %% [markdown]
# ### Using sentence embedding model to find out top 30 similar set

# %%
# calculate embeddings
verb_phrase_emb_dict = dict()
for p in tqdm(verb_phrase_set):
    verb_phrase_emb_dict[p] = model.encode(p)
# Out:
# /tmp/ipykernel_5552/2556447431.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for p in tqdm(verb_phrase_set):
#   0%|          | 0/1104 [00:00<?, ?it/s]

# %%
from IPython.display import HTML as html_print

def cstr(s, color='black'):
    return "<text style=color:{}>{}</text>".format(color, s)

left, word, right = 'foo' , 'abc' , 'bar'
html_print(cstr(' '.join([left, cstr(word, color='yellow'), right]), color='black') )
# Out:
# <text style=color:black>foo <text style=color:yellow>abc</text> bar</text>

# %%
def calculate_cosine_distance(emb_one, emb_two):
    return cosine(emb_one, emb_two)

def find_sentence_three(phrase, training_dict):
    output_arr = []
    for key, val in training_dict.items():
        if phrase in val['spell_correction_txt']:
            
            output_arr.append(val['spell_correction_txt'])
    shuffle(output_arr)
    return output_arr[:3]

# %%
verb_phrase_close_phase_dict = dict()
for key, val in tqdm(verb_phrase_emb_dict.items()):
    calculate_distance_partial = partial(calculate_cosine_distance, emb_one = val)
    sorted_arr = sorted(verb_phrase_emb_dict, key=lambda k: calculate_distance_partial(emb_two=verb_phrase_emb_dict.get(k)))
    top_ten_arr = sorted_arr[1:31] # index 0 is itself
    verb_phrase_close_phase_dict[key] = top_ten_arr
# Out:
#   0%|          | 0/1104 [00:00<?, ?it/s]

# %%
hard_negative_verb_phrase_dict = dict()
for ind, (key, val) in enumerate(verb_phrase_close_phase_dict.items()):
    print(f"{ind+1}/{len(verb_phrase_close_phase_dict)} Verb Key:", key)
    print("Example:")
    egsent_arr =  find_sentence_three(key, raw_instruction_dict)
    for sent in egsent_arr:
        print("\t",sent)
    print(f"Similar Phrase:")
    for i in range(0, 30, 5):
        print('\t', val[i:i+5])
    print("")
    # now enter hard negative manually 
    while True:
        x = input('input hard negative verb arr')
        try:
            eval_x = eval(x)
            if type(eval_x) != list:
                raise RuntimeError('not a list!')
            break # break the while true loop
        except Exception as e:
            print(e)
            print("Sorry Try again")
    hard_negative_verb_phrase_dict[key] = eval_x
    # refresh 
    clear_output(wait=False)
    time.sleep(0.2)

# %%
len(hard_negative_verb_phrase_dict)
# Out:
# 1104

# %%
with open('train_data/action_phrase_hard_negative_dict.pkl', 'wb') as f:
    pickle.dump(hard_negative_verb_phrase_dict, f)

# %%
eval("['hello'")
# Out:
# Traceback (most recent call last):
#
#   File ~/anaconda3/envs/atari_clean/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3378 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In [32], line 1
#     eval("['hello'")
#
#   File <string>:1
#     ['hello'
#            ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# ## Analyse Noun Phrase Set

# %%
with open('train_data/noun_phrase_chunk_set.pkl', 'rb') as f:
    noun_phrase_set = pickle.load(f)

# %%
noun_phrase_set
# Out:
# {'two jumps',
#  'the skull to the right',
#  'left and walk',
#  'the second one',
#  'the hanging purple rod',
#  'a small step towards the barrier',
#  'exit ladder',
#  'mid level',
#  'the endow',
#  'the column',
#  'the snake other side',
#  'the next side',
#  'the ladder in the blue world',
#  'the surroundings',
#  'moving horizontal line to the right',
#  'another step',
#  'the blue lines',
#  'the electrical field',
#  'the far right edge',
#  'the rope to the floor',
#  'a few more',
#  'the solid brick',
#  'playing',
#  'down side',
#  'you to the ground',
#  'the half way point on the ladder',
#  'big ladder',
#  'a bit at the ladder',
#  'the left snake',
#  'left side rope',
#  'step left',
#  'the ladder in the middle',
#  'this jump',
#  'green creature to the right',
#  'three times to the edge',
#  '5 rungs of the blue ladder',
#  'the edge of the ledge',
#  'the left platform',
#  'fast search',
#  'a different area',
#  'the hammer power',
#  'head',
#  'this person',
#  'green creature',
#  'the roller',
#  'the flame',
#  'the right until the end',
#  'object',
#  'the platform',
#  'your left into next screen',
#  'the ladder to the ground',
#  'the stick',
#  'ladder to first level',
#  'one step to the left',
#  'column',
#  'the game',
#  'the ladder into the new zone',
#  'the ladder to the right edge',
#  'ladder',
#  'purple pole to top',
#  'the bottom of the rope',
#  'the latter to the next screen',
#  'more',
#  'the first blue lines on the background',
#  'one step to the right',
#  'jump to the skull',
#  'the floor',
#  'the pole jump',
#  'the ladder on standing',
#  'the gold coin by little jump',
#  'the right past the ladder',
#  'the bouncing skulls',
#  'man',
#  'the left over the skull',
#  'an moment',
#  'spider on your way',
#  'the ladder into the next world',
#  'left',
#  'five steps',
#  'up side',
#  'three rungs',
#  'the yellow pole',
#  'the left over the snakes',
#  'enemies',
#  'the top platform',
#  'the ledge onto the rope',
#  'a ledge',
#  'the lava pit',
#  'another level',
#  'right side in laser beams',
#  'left 3 steps',
#  'the first 2 and jump',
#  'once clip on the stick',
#  'the platform on the right',
#  'the two laser ray',
#  'the level',
#  'one right leg',
#  'right and climb ladder',
#  'go to the other place',
#  'the enemy',
#  'a jump',
#  'green spider',
#  '1 more step to the right',
#  'a screen with wavy blue lines',
#  'hero',
#  'the beam',
#  'clear area',
#  'snakes on either side',
#  'laser climb on other side',
#  'the man',
#  'the next area to the left',
#  'a few more steps',
#  'the exact position',
#  'ladder for spider',
#  'the left past the ladder',
#  'the creature',
#  'left side with 2 jumps',
#  'the flaming torch',
#  'the snake to the left',
#  'the bride',
#  'dodge floating skulls',
#  '2 times',
#  'the top middle ledge',
#  'ladder into new zone',
#  'upside in another location',
#  'about 5 steps to the left',
#  'down ladder to the bottom',
#  'solid ground',
#  'the all',
#  'nether way',
#  'the reach to the goal',
#  'skull head',
#  'all the way to the right',
#  'the right large platform',
#  'snake',
#  'the top ledge',
#  'the yellow thing',
#  'the first floor',
#  'safe zone',
#  '1 second',
#  'the ladder into the next area',
#  'the middle of the room',
#  'the upper',
#  'end of solid ledge',
#  'the poles',
#  'a new zone',
#  'the room to the left',
#  'claim down the ladder',
#  'the bars',
#  'the ladder before crab catches',
#  'the right toward the key',
#  'the downside',
#  'hammer',
#  'the next set of lines',
#  'the electric circuit',
#  'crab',
#  'one long step',
#  'the fading columns of electricity',
#  'the end of screen',
#  'the pole onto the platform',
#  'laser beams',
#  'the right edge of the screen',
#  'the things',
#  'pipe',
#  'ladder jump and jump',
#  'the wakefield',
#  'ladder to your left',
#  'the bridge over the lava',
#  'the right climb down the ladder',
#  'next block',
#  'three times',
#  'correct time',
#  'the bridge to the right',
#  'the left and jump',
#  'water',
#  'another world',
#  'just one jump',
#  'skull side',
#  'the ladder to the purple room',
#  'the right room',
#  'ground portion of ladder',
#  'those lasers',
#  'a rope to your right',
#  'top of the bug',
#  'a moment',
#  'heads',
#  '4 steps to the left',
#  'the two white walls',
#  'this just move',
#  'your side',
#  'the other side',
#  'the floating ledges on the right',
#  'the room on the right',
#  'vertical lines',
#  'the platform to the other side',
#  'a height',
#  'key by little jump',
#  'the right onto the next screen',
#  'climb down the ladder',
#  'ladder to the left',
#  'jump on the platform',
#  'the middle ledge to the rope',
#  'screen',
#  'stay quiet',
#  'one step down the ladder',
#  'the steps on the right',
#  'cross between the laser ray',
#  'the rope in the middle',
#  'field',
#  'top',
#  'a couple of times',
#  'what',
#  'the wall on the right',
#  'grab purple pole',
#  'the right into the lines',
#  'one rung',
#  'the line on the left',
#  'the ladder into the bug',
#  'two small steps to the left',
#  'golden key collection',
#  'the right',
#  'the left rope',
#  'ladder to ground',
#  'the ladder before spider',
#  'the water level',
#  'the right of the gem',
#  '1 big step',
#  'the force field',
#  'right time',
#  'the ladder to the next area',
#  'the ledge on the right',
#  'floating skeleton heads',
#  'this and laser climb',
#  'the blue waves',
#  'the road',
#  'one monster',
#  'the insect obstacle',
#  'the wall to the right',
#  'the skulls in the next room',
#  'the right wall',
#  'the moving dashes',
#  'land',
#  'stair',
#  'the new zone',
#  'spawn',
#  'one spot to the right',
#  'the disappearing lines',
#  'the hero',
#  'the ladder at the level',
#  'the skulls to the ladder',
#  'slightly right side',
#  'the wall',
#  'the blinking stair',
#  'two steps',
#  'the gem',
#  'the ball',
#  'brief turn',
#  'each side',
#  'the electricity',
#  'exit ladder and face right',
#  'it to the horizontal line',
#  'the first line of electric and pause',
#  'put',
#  'the first snake',
#  'bridge',
#  'your way on the ladder',
#  'the force',
#  'upside',
#  'two times to the left',
#  'a little bit up the ladder',
#  'ladder into next screen',
#  'little',
#  'the creature on the left',
#  'a new screen',
#  'the thing on the right',
#  'the second snake',
#  'the lines track',
#  'the edge of the pit',
#  'a little bit to the left',
#  'death',
#  'sticks',
#  'each one',
#  'the ladder on climb',
#  'skull roll',
#  'your place',
#  'the laser beam',
#  'the room of walls',
#  'the move to the right',
#  'the hammer',
#  'the wavy lines',
#  'rooms',
#  'second room',
#  '2 jumps to the right',
#  'the right jump',
#  'the rope to the left',
#  'the item',
#  'the last area',
#  'the platform towards the bottom',
#  'the hanging pole',
#  'go to upside',
#  'the steps on the right side',
#  'success',
#  'a little bit to the right',
#  'the previous screen',
#  'the ladder to the left',
#  'two times',
#  'next location',
#  'all the way to the left',
#  'over 2 snakes',
#  'the left onto the rope',
#  'jump on each ladder',
#  'jump across the bridge',
#  'just little move to right side',
#  'the room',
#  'a jump to the right',
#  'the reward',
#  'the move',
#  'another location',
#  'the flashing lights',
#  'the box',
#  'that of the snake',
#  'the skeleton head',
#  'running and jumping after that',
#  'four consecutive times',
#  'hat',
#  'the next room',
#  'obstruction',
#  'bottom of ladder',
#  'the top of the ledge',
#  'wall',
#  'right side of room',
#  'the objects',
#  'ladder in the center',
#  'wait few minutes',
#  'slow walking',
#  'the rope and right walk',
#  'the first electricity',
#  'jewel',
#  'the top of pole',
#  'purple hanging pole',
#  'the next room in the new room',
#  'the ditch',
#  'front of barrier',
#  'one snake',
#  'rays',
#  'the gate',
#  'straight',
#  'the vertical lines',
#  'the latter',
#  'the fire',
#  'left jump to the rope',
#  'the water crater',
#  'waves',
#  'the laser beam side',
#  'the the ground',
#  'the be lines',
#  'starting position',
#  'the white pole',
#  'item',
#  'the right into the next area',
#  'the magical walls',
#  'the skull to the left',
#  'continuous jump over upside',
#  'move slight down the ladder',
#  'left and climb ladder',
#  'same place',
#  'the vibration',
#  'the left toward the rope',
#  'little jump',
#  'that place',
#  'the right end',
#  'the next level',
#  'the correct time ladder',
#  'the other ladder',
#  'word ladder',
#  'stationary to the left corner',
#  'no movements',
#  'right and wait',
#  'platform before bridge',
#  'small steps to the left',
#  'same direction',
#  'the leftwards',
#  'the hidden wall',
#  'the green enemy',
#  'the mote',
#  'the next level with the ladder',
#  'a sword',
#  'the ladder onto the next level',
#  'the drawbridge',
#  'two steps to the right',
#  'little front',
#  'flashing lights',
#  'a little bit',
#  'white bars',
#  'the right down the head',
#  '1 small step',
#  'the doors',
#  'the next end',
#  'the ledge',
#  'a quarter step',
#  'this skull rolling',
#  'your right to next room',
#  'the middle ledge',
#  'the right ledge',
#  'one',
#  'a bit on the rope',
#  'the left on the rope',
#  'the run',
#  'ledge',
#  'the skeletons',
#  'climbs above the ladder',
#  'same level',
#  'the opposite edge',
#  'the floating skulls',
#  'the right , climb ladder',
#  'a while',
#  'the left of the skull',
#  'the next platform',
#  'opposite side',
#  'rope',
#  'few steps',
#  'white lines',
#  'the player health',
#  'wait and go',
#  'the previous room',
#  'ord columns',
#  'ledge onto the rope',
#  'the space',
#  'the ladder over the checked bridge',
#  'left little jump over the snake',
#  'your way to the left',
#  'a',
#  'jump to the middle platform',
#  'second pair of barriers',
#  'right and jumping',
#  'last 2 steps',
#  'great escape',
#  'the ground',
#  'game',
#  'moves to the right',
#  'front of the pit',
#  'rope to platform',
#  'skelton game',
#  'the key by little jump',
#  'a little bit more',
#  'the lasers',
#  'the lines on the left',
#  'a little bit down the ladder',
#  'the barrier to your right',
#  '3 more times on the squiggle bricks',
#  'nothing',
#  'the left to the room',
#  'another one',
#  'little after laser beam',
#  'front of the barrier',
#  'ladder down this light button',
#  'the golden part',
#  '1 walk',
#  'form ladder',
#  'a few steps to the right',
#  'this away ladder',
#  'the upstairs',
#  'the green one',
#  'little move in downside',
#  'a little up the latter',
#  'the left on the blue lines',
#  'the left and down the ladder',
#  'it to the right',
#  'the electric shock',
#  'step to the right',
#  'the jewel',
#  'white barriers',
#  'the platforms to the right',
#  'the obstacle to the right',
#  'the ladder past the bug',
#  'some wavy lines',
#  'the crab',
#  'the beams from the ground',
#  'the other way',
#  'the land',
#  'the left',
#  'moves to the right stop',
#  'about 2 steps to the left',
#  'shock columns',
#  'upstairs to that aim',
#  'the bottom',
#  'the right into the next room',
#  'the fire piece',
#  'that person',
#  'little time',
#  'sometime',
#  'ladder to old zone',
#  'a couple of steps',
#  'the ladder to the right',
#  'focus',
#  'a little',
#  'the string or thread',
#  'the large platform',
#  'other side',
#  'half way down the ladder',
#  'a couple of seconds',
#  'fast move',
#  'three steps',
#  'the help of ladder',
#  'half',
#  'they',
#  'walk to the right',
#  'another side',
#  'the disappearing floor',
#  'the upside by ladder',
#  'them',
#  'the coin from the left turn',
#  'rope in hung',
#  'little time near the laser beam',
#  'string',
#  'step towards barrier',
#  'clip down the ladder',
#  'this running to next ladder spider',
#  'the pattern to the forcefield',
#  'right stop',
#  'the ledge toward the rope',
#  'the ladder to the blue room',
#  'the rope to the right',
#  'the two rooms',
#  'a short time',
#  'the right place',
#  'little up',
#  'the right voiding barriers',
#  'the two skulls down the ladder',
#  'the next bars',
#  'jump and touch snake',
#  'jumps',
#  'right and left side',
#  'three time',
#  'three steps to the right',
#  'the object to the right',
#  'the electric fades',
#  'this away',
#  'the pulsing platform',
#  'some second',
#  'the green spider',
#  'spider leave',
#  'the rolling skull',
#  'the door',
#  'the bridge to the left',
#  'all the way',
#  'the right of the room',
#  'slightly left walk',
#  'the golden key',
#  'water level',
#  'the ladder below the skulls',
#  'st stage to and stage',
#  'two steps left pause',
#  'green',
#  'the middle stick down skull',
#  'the vanishing platforms',
#  'ladder to original point',
#  'right and jump',
#  'the',
#  'right side in climb ladder',
#  'the key jump',
#  'the top of ladder',
#  'one short step',
#  'the the right climb',
#  'leaser beam',
#  'the first wall',
#  'new window',
#  'ledge before bridge',
#  'claim',
#  'the coin on the left',
#  'platform on left',
#  'new zone',
#  'the dots',
#  'the moving platform',
#  'the laser light',
#  'the ladder little move',
#  'the middle slab',
#  'barrier light',
#  'the buzzsaw',
#  'the crab looking thing',
#  'the right over the skull',
#  'the platform on the left',
#  'two jump',
#  'the rope to the top',
#  'a step to the left',
#  'the middle',
#  'jump 3 times',
#  'the next room on the right',
#  'the later',
#  'move step of the upstairs',
#  'waiting person',
#  'go to the top side',
#  'skeleton head',
#  'two step to right',
#  'the pole to the right',
#  'a bit more',
#  'the rope to the other end',
#  'the next room down the ladder',
#  'vertical line',
#  'the ladder into the purple room',
#  'the snake on the right',
#  'your self',
#  'the white barriers',
#  'a couple small steps',
#  'the ladder for a bit',
#  'the side of left',
#  'leftside',
#  'go to the other side',
#  'the next location',
#  'the white skull',
#  'stable fun to the left',
#  'the solid platform',
#  'it to the left',
#  'platform on the right',
#  'platform',
#  'the platform onto the yellow pole',
#  'the platforms',
#  'right jump',
#  'the jump over the snake',
#  'ladder underside',
#  'one time',
#  'old zone',
#  'a larger jump to the left',
#  'snake and climb ladder',
#  'move to upside',
#  'the gift',
#  'a right',
#  'spider skills',
#  'the next screen',
#  'the right edge',
#  'next screen',
#  'the skull',
#  'left side to ladder',
#  'the center platform',
#  'room with ladder',
#  'the ladder for little time',
#  'one place',
#  'no next level',
#  'your legs',
#  'the right time',
#  'inverse move',
#  'the edge of the cliff',
#  'upwards',
#  'the ladder to the down',
#  'you',
#  'the nice place',
#  'the banner',
#  '3 times',
#  'flame',
#  'the right of the screen',
#  'out touch',
#  'onside ladder',
#  'the next wall',
#  'temporary steps',
#  'the obstacle',
#  'the worm',
#  'the force fields to your left',
#  'the horizontal moving lines',
#  'the sand',
#  'the ledge on the left',
#  'the middle of the barriers',
#  'the background stripes',
#  'the up',
#  'insect',
#  'the mid point',
#  'leaf',
#  'hop to the left',
#  'jump to the right',
#  'the bug',
#  'the key to the left',
#  'the top of the rope',
#  'the right towards the ladder',
#  'the thin purple stick',
#  'use ladder',
#  'middle of screen',
#  'the large middle platform',
#  'the rope to the ground',
#  'stationary long bar',
#  'ladder in another location',
#  'the left towards the ladder',
#  'climb rope',
#  'the middle of ladder',
#  'the next area',
#  'a floor',
#  'the left into the next area',
#  'the space between the rising horizontal lines',
#  'the fast run',
#  'the correct time',
#  'the left with the skulls',
#  'top of ladder',
#  'one rope',
#  'half way to the ladder',
#  'the top middle platform to the left',
#  'the snakes',
#  'the leftmost room',
#  'the stage',
#  'the squiggly lines',
#  'the ladder by half a rung',
#  'walls',
#  'top of purple pole',
#  'ladder and zone end',
#  'light',
#  'your right',
#  'a third of the ladder',
#  'your head',
#  'a barrier',
#  'the next level to upstairs',
#  'right 3 steps',
#  'the room in the right',
#  'the ladder on the right',
#  'all of the way',
#  'the gold hammer',
#  'next level',
#  'the bars on the right',
#  'the nearest rail',
#  'inch',
#  'current screen',
#  'cross across the laser beam',
#  'a bit below the ground',
#  'little bit',
#  'beams',
#  'jumping',
#  'a bit at the bottom',
#  'room',
#  'hop',
#  'the right onto the ledge',
#  'steps',
#  'latter',
#  'top of stairs',
#  'snack',
#  'the left behind the spider',
#  'upside by ladder',
#  'two rungs down the ladder',
#  'that object',
#  'pole',
#  'the disappearing steps',
#  'the rob',
#  'upstairs',
#  'the barriers',
#  'the green ladder',
#  'the purple wall',
#  'snake to the ladder',
#  'snakes',
#  'go',
#  'a step to the right',
#  'the left in between the flashing poles',
#  'the up and fast run',
#  'step to right',
#  'the ladder to the next level',
#  'skull jump ladder upside',
#  'the ladder wait crab',
#  'the middle of the ladder',
#  'the sword on the left',
#  'middle',
#  'the floating flashing bridge to the right',
#  'just one step towards left side',
#  'little place',
#  'laser',
#  'the flashing lines',
#  'next clear area',
#  'walk',
#  'climb ladder',
#  'a few stops',
#  'the sword',
#  'walk towards left',
#  'the road in upside',
#  'skull jump to this ladder upside',
#  'the right stop',
#  'the ledge toward the left',
#  'anything',
#  'left turn',
#  'ladder for go',
#  'another move',
#  'first floor',
#  'the key on the right',
#  'the next pair of barriers',
#  'the right to the next room',
#  'the rope to safety',
#  'almost half way',
#  'this golden key collection',
#  'the ladder to the top',
#  'the ladder by fast move',
#  'two times break',
#  'the upper edge',
#  'the right edge of the map',
#  'little move to upside',
#  'a black screen',
#  'ladder to another new zone',
#  'the floor de',
#  'one rung on the ladder',
#  'letter',
#  'the hanging purple bar',
#  'the left room up the ladder',
#  'the go',
#  'one ladder rung',
#  'place on the ladder',
#  'the platform to the left',
#  'st',
#  'the down',
#  'a jump to the left',
#  'halfway point of ladder',
#  'the ladder to the next zone',
#  'no way',
#  'the right side of the screen',
#  'our hero',
#  'a few steps',
#  'don',
#  'the ladder towards upside',
#  'enemy',
#  'the edge of the walls',
#  'the rope to the platform',
#  'the snake room',
#  'left to right walk',
#  'skull rolling',
#  'the snack',
#  'go to the top place',
#  'ledge on right side',
#  'spider passes',
#  'the article purple line',
#  'the point',
#  'the right into an bug',
#  'right screen',
#  'floor level of snakes',
#  'next room',
#  'the top of the purple room',
#  'his right',
#  'step left side',
#  'the bridge',
#  'the jump',
#  '1 jump',
#  'skull',
#  'the purple platform to your right',
#  'the snake on your way',
#  'a couple steps down the ladder',
#  'the temporary rope',
#  'perfect time',
#  'the left of the ladder',
#  'the left room',
#  'jump and back right side jump',
#  'that',
#  'your way to the right',
#  'the skulls to the right',
#  'the other place',
#  'club up the ladder',
#  'ladder two rungs',
#  'fence',
#  'the right one screen',
#  'a split second',
#  'the white string',
#  'step',
#  'the one cross',
#  'this rope',
#  'the right over the spider',
#  'the right to the edge',
#  'side',
#  'one more possible',
#  'the rays',
#  'staircase',
#  'jump thrice',
#  'the ladder',
#  'a couple steps',
#  'a look of that timing',
#  'the beam side',
#  'the left side',
#  'the left toward the ladder',
#  'the other snake',
#  'the ladder for visibility',
#  '1 st level',
#  'the place before flames',
#  'the green',
#  'the center of the room',
#  'left jump',
#  'the rising lines',
#  'middle of steak and right side ladder',
#  'the object',
#  'slight right',
#  'the ladder onto the brick level',
#  'the blue floor',
#  'this person ladder jump',
#  'coin',
#  'the left jump',
#  'the head',
#  'purple pole',
#  'center of screen',
#  'right side and death',
#  'one to the left',
#  'a second',
#  'jump for person',
#  '6 times',
#  'gold',
#  'hold of the rope',
#  'right side in lost end',
#  'now',
#  'the proper time',
#  'upside another location',
#  'the back side',
#  'two rungs of the ladder',
#  'the life edge',
#  'the down place',
#  'the right jump on the rope',
#  'a little bit to right',
#  'top of the ladder',
#  'snake kitty irundhu',
#  'shuffle in place',
#  'the ledges to the top',
#  'the skeleton',
#  'the fast and jump',
#  'the danger way',
#  'the person',
#  'the moving bar',
#  'the gold coin',
#  'the black room',
#  'just little move in laser beam',
#  'the rope on the left',
#  'a little bit toward the ladder',
#  'next stage',
#  'the side',
#  'edge',
#  'the left through the lasers',
#  'a few steps down ladder',
#  'the two snake',
#  'left and right side',
#  'the ladder to the first floor',
#  'the rope onto the large platform',
#  'key',
#  'approach',
#  'person',
#  'all the way down the ladder',
#  'the room to the right',
#  'the ladder past the snake',
#  'middle of the laser',
#  'it to the left horizontal line',
#  'down ladder turn left jump over snake',
#  'left & jump',
#  'the stairs',
#  'skulls',
#  'slightly walk',
#  'the moving lines',
#  'the step',
#  'the top of the green ladder',
#  'left side',
#  'the slap',
#  'moves',
#  'the right across the force',
#  'the middle point',
#  'the bottom of the ladder',
#  'the path',
#  'the right past the flickering lines',
#  'ones',
#  'the vertical line',
#  'front side snake coming ladder',
#  'go to other place',
#  'the same place',
#  'a few steps on the left',
#  'the purple vertical bar',
#  '3 times on the ladder',
#  'one long jump',
#  'the void',
#  'bottom',
#  'right by walk',
#  'the ladder toward the next room',
#  'thrice',
#  'points',
#  'the ladder on your left',
#  'another side in laser beam',
#  'the laser ray',
#  'a step',
#  'them at right time',
#  'the upward moving blocks',
#  'this running',
#  'he',
#  'two seconds',
#  'barrier',
#  'few seconds',
#  'your in front',
#  'your current position',
#  'the electric buzz',
#  'time',
#  'the blue squiggly floor',
#  'left and jumping collecting key',
#  'the lines',
#  'place',
#  'floating skulls',
#  'a right into the next area',
#  'jump of purple pole',
#  'walk semi',
#  'the bug passes',
#  'the laser ray for sometime',
#  'all the way up the ladder',
#  'the skull into the brown stuff',
#  'the up and right climb above the ladder',
#  'the human skull and go',
#  'just little move',
#  'the ladder above the bug',
#  'creature',
#  'the sword and key',
#  'a step down the ladder',
#  'hesitation',
#  'this laser light',
#  'quickly one spot',
#  ...}

# %%
# calculate embeddings
noun_phrase_emb_dict = dict()
for p in tqdm(noun_phrase_set):
    noun_phrase_emb_dict[p] = model.encode(p)
# Out:
#   0%|          | 0/1579 [00:00<?, ?it/s]

# %%
noun_phrase_close_phase_dict = dict()
for key, val in tqdm(noun_phrase_emb_dict.items()):
    calculate_distance_partial = partial(calculate_cosine_distance, emb_one = val)
    sorted_arr = sorted(noun_phrase_emb_dict, key=lambda k: calculate_distance_partial(emb_two=noun_phrase_emb_dict.get(k)))
    top_ten_arr = sorted_arr[1:31] # index 0 is itself
    noun_phrase_close_phase_dict[key] = top_ten_arr
# Out:
#   0%|          | 0/1579 [00:00<?, ?it/s]

# %%
hard_negative_noun_phrase_dict = dict()

for ind, (key, val) in enumerate(noun_phrase_close_phase_dict.items()):
    print(f"{ind+1}/{len(noun_phrase_close_phase_dict)} Noun Key:", key)
    print("Example:")
    egsent_arr =  find_sentence_three(key, raw_instruction_dict)
    for sent in egsent_arr:
        print("\t",sent)
    print(f"Similar Phrase:")
    for i in range(0, 30, 3):
        print('\t', val[i:i+3])
    print("")
    # now enter hard negative manually 
    while True:
        x = input('input hard negative noun arr')
        try:
            eval_x = eval(x)
            if type(eval_x) != list:
                raise RuntimeError('not a list!')
            break # break the while true loop
        except Exception as e:
            print(e)
            print("Sorry Try again")
    hard_negative_noun_phrase_dict[key] = eval_x
    # refresh 
    clear_output(wait=False)
    time.sleep(0.2)

# %%
with open('train_data/noun_phrase_hard_negative_dict.pkl', 'wb') as f:
    pickle.dump(hard_negative_noun_phrase_dict, f)

# %% [markdown]
# ## Notes when replacing the phrase
#
# 1. you need to have spaces to the left and right e.g., " walk towards "
# 2. there might be no hard negative elements
#
# ### Some wrong phrase correct them first before replacing
# 1. 'claim" -> 'climb'
# 2. 'club' -> 'climb'
# 3. 'done' -> 'do not'
# 4. 'clip' -> 'climb'
# 5. 'clumping' -> 'climbing'
# 6. 'clime' -> 'climb'
# 7. 'hope' -> 'hop'
# 8. 'toe' -> 'to'
# 9. 'endow' -> 'end'
# 10. 'latter' -> 'ladder'
# 11. 'bride' -> 'bridge'
# 12. 'leaser' -> 'laser'
# 13. 'later' -> 'ladder'
# 14. 'leaf' -> 'left'
# 15. 'snack' -> 'snake'
# 16. 'rob' -> 'rope'
# 17. "don' -> 'do not'
# 18. 'article' -> 'verticle'
# 19. 'life edge' -> 'left edge'
# 20. 'done' -> 'do not'
# 21. 'ans' -> 'and'
# 22. 'skelton' -> 'skeleton'
# 23. 'skilled' -> 'skull'
